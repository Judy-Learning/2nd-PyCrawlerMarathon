# %% [markdown]
# # Wikipedia爬蟲練習
# ## 範例：練習是從Wikipedia中爬取文章。先定義一個搜尋的關鍵字，擷取該關鍵字詞的文章。

# %%
import requests
import re 
from bs4 import BeautifulSoup

# %% [markdown]
# ### 先定義一個我們想搜尋的字詞，並將它轉換成UTF-8編碼後的URL

# %%
input_keyword = "網路爬蟲"  # 這裡可以自己定義有興趣的關鍵字

utf8_url = repr(input_keyword.encode('UTF-8')).upper()  # 編碼成UTF-8並轉成大寫字元
utf8_url = utf8_url.replace("\\X", "%")                 # 用 '%' 取代 '\X' 
print("%s: %s" % (input_keyword, utf8_url[2:-1:1]))     # 擷取中間的編碼結果

# 組成Wiki關鍵字搜尋的網址格式
root_keyword_link = '/wiki/' + utf8_url[2:-1:1]
print(root_keyword_link)
# Out:
# 網路爬蟲: %E7%B6%B2%E8%B7%AF%E7%88%AC%E8%9F%B2
# /wiki/%E7%B6%B2%E8%B7%AF%E7%88%AC%E8%9F%B2

# %% [markdown]
# ### 範例1：送出關鍵字請求後，爬取該關鍵字的文章內容

# %%
# 模擬封包的標頭
headers = {
    'authority': 'zh.wikipedia.org',
    'method': 'GET',
    'path': '/wiki/' + root_keyword_link,
    'scheme': 'https',
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3',
    'accept-encoding': 'gzip, deflate, br',
    'accept-language': 'zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7,zh-CN;q=0.6',
    'cookie': 'GeoIP=TW:TPE:Taipei:25.05:121.53:v4; TBLkisOn=0; mwPhp7Seed=8b8; WMF-Last-Access-Global=04-Jun-2019; WMF-Last-Access=04-Jun-2019',
    'dnt': '1',
    #'if-modified-since': 'Tue, 04 Jun 2019 12:03:22 GMT',
    'referer': 'https://zh.wikipedia.org/wiki/Wikipedia:%E9%A6%96%E9%A1%B5',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Safari/537.36'
}    

url = 'https://zh.wikipedia.org' + root_keyword_link  # 組合關鍵字查詢URL
resp = requests.get(url, headers=headers)
resp.encoding = 'utf-8'

html = BeautifulSoup(resp.text, "lxml")
content = html.find(name='div', attrs={'id':'mw-content-text'}).find_all(name='p')

#
# 解析回傳資料，並萃取文章內容
#
for paragraph in content:
    print(paragraph.get_text())
# Out:
# 網路爬蟲（英語：web crawler），也叫網路蜘蛛（spider），是一種用來自動瀏覽全球資訊網的網路機器人。其目的一般為編纂網路索引（英語：Web indexing）。
#
# 網路搜尋引擎等站點通過爬蟲軟體更新自身的網站內容（英語：Web content）或其對其他網站的索引。網路爬蟲可以將自己所存取的頁面儲存下來，以便搜尋引擎事後生成索引（英語：Index (search engine)）供用戶搜尋。
#
# 爬蟲存取網站的過程會消耗目標系統資源。不少網路系統並不默許爬蟲工作。因此在存取大量頁面時，爬蟲需要考慮到規劃、負載，還需要講「禮貌」。 不願意被爬蟲存取、被爬蟲主人知曉的公開站點可以使用robots.txt檔案之類的方法避免存取。這個檔案可以要求機器人（英語：Software agent）只對網站的一部分進行索引，或完全不作處理。
#
# 網際網路上的頁面極多，即使是最大的爬蟲系統也無法做出完整的索引。因此在公元2000年之前的全球資訊網出現初期，搜尋引擎經常找不到多少相關結果。現在的搜尋引擎在這方面已經進步很多，能夠即刻給出高品質結果。
#
# 爬蟲還可以驗證超連結和HTML代碼，用於網路抓取（英語：Web scraping）（參見資料驅動編程（英語：Data-driven programming））。
#
# 網路爬蟲也可稱作網路蜘蛛[1]、螞蟻、自動索引程式（automatic indexer）[2] ，或（在FOAF（英語：FOAF (software)）軟體中）稱為網路疾走（web scutter）。[3]
#
# 網路爬蟲始於一張被稱作種子的統一資源位址（URL）列表。當網路爬蟲存取這些統一資源定位器時，它們會甄別出頁面上所有的超連結，並將它們寫入一張「待訪列表」，即所謂爬行疆域（英語：crawl frontier）。此疆域上的URL將會被按照一套策略迴圈來存取。如果爬蟲在執行的過程中複製歸檔和儲存網站上的資訊，這些檔案通常儲存，使他們可以較容易的被檢視。閱讀和瀏覽他們儲存的網站上並即時更新的資訊，這些被儲存的網頁又被稱為「快照」。越大容量的網頁意味著網路爬蟲只能在給予的時間內下載越少部分的網頁，所以要優先考慮其下載。高變化率意味著網頁可能已經被更新或者被取代。一些伺服器端軟體生成的URL（統一資源定位符）也使得網路爬蟲很難避免檢索到重複內容。
#
# 但是網際網路的資源卷帙浩繁，這也意味著網路爬蟲只能在一定時間內下載有限數量的網頁，因此它需要衡量優先順序的下載方式。有時候網頁出現、更新和消失的速度很快，也就是說網路爬蟲下載的網頁在幾秒後就已經被修改或甚至刪除了。這些都是網路爬蟲設計師們所面臨的兩個問題。
#
# 再者，伺服器端軟體所生成的統一資源位址數量龐大，以至網路爬蟲難免也會採集到重複的內容。根據超文字傳輸協定，無盡組合的參數所返回的頁面中，只有很少一部分確實傳回正確的內容。例如：數張快照陳列室的網站，可能通過幾個參數，讓用戶選擇相關快照：其一是通過四種方法對快照排序，其二是關於快照解析度的的三種選擇，其三是兩種檔案格式，另加一個用戶可否提供內容的選擇，這樣對於同樣的結果會有48種（4*3*2）不同的統一資源位址與其關聯。這種數學組合替網路爬蟲造成了麻煩，因為它們必須越過這些無關指令碼變化的組合，尋找不重複的內容。
#
# 爬蟲的實現由以下策略組成：[4]
#
# 爬蟲可能只想搜尋HTML頁面而避免其他MIME 類型。為了只請求HTML資源，爬蟲在抓取整個以GET方式請求的資源之前，通過建立HTTP的HEAD請求來決定網路資源的MIME類型。為了避免發出過多的請求，爬蟲會檢查URL和只請求那些以某些字元（如.html, .htm, .asp, .aspx, .php, .jsp, .jspx 或 / ）作為字尾的URL。這個策略可能會跳過很多HTML網路資源。
#
# 有些爬蟲還能避免請求一些帶有「?」的資源（動態生成）。為了避免掉入從網站下載無限量的URL的爬蟲陷阱。不過假若網站重寫URL以簡化URL的目的，這個策略就變得不可靠了。
#
# 爬蟲通常使用某些URL規格化的方式以避免資源的重複爬取。URL規格化，指的是以某種一致的方式修改和標準化URL的過程。這個過程有各種各樣的處理規則，包括統一轉換為小寫、移除「.」和「..」片段，以及在非空路徑里插入斜杆。
#
# 有些爬蟲希望從指定的網站中儘可能地爬取資源。而路徑上移爬蟲就是為了能爬取每個URL里提示出的每個路徑。[5] 例如，給定一個Http的種子URL: http://llama.org/hamster/monkey/page.html ，要爬取 /hamster/monkey/ ， /hamster/ 和 / 。Cothey發現路徑能非常有效地爬取獨立的資源，或以某種規律無法在站內部連結接爬取到的資源。
#
# 對於爬蟲來說，一個頁面的重要性也可以說是，給定查詢條件一個頁面相似效能起到的作用。網路爬蟲要下載相似的網頁被稱為主題爬蟲或局部爬蟲。這個主題爬蟲或局部爬蟲的概念第一次被Filippo Menczer[6][7] 和  Soumen Chakrabarti 等人提出的。[8]
#
# 網站的屬性之一就是經常動態變化，而爬取網站的一小部分往往需要花費幾個星期或者幾個月。等到網站爬蟲完成它的爬取，很多事件也已經發生了，包括增加、更新和刪除。
# 在搜尋引擎的角度，因為沒有檢測這些變化，會導致儲存了過期資源的代價。最常用的估價函式是新鮮度和過時性。
# 新鮮度：這是一個衡量抓取內容是不是準確的二元值。在時間t內，倉庫中頁面p的新鮮度是這樣定義的：
#
# 過時性:這是一個衡量本地已抓取的內容過時程度的指標。在時間t時，倉庫中頁面p的時效性的定義如下：
#
# 爬蟲相比於人，可以有更快的檢索速度和更深的層次，所以，他們可能使一個站點癱瘓。不需要說一個單獨的爬蟲一秒鐘要執行多條請求，下載大的檔案。一個伺服器也會很難回應多執行緒爬蟲的請求。
# 就像Koster所注意的那樣，爬蟲的使用對很多工作都是很有用的，但是對一般的社區，也需要付出代價。使用爬蟲的代價包括：[9]
#
# 對這些問題的局部解決方法是漫遊器排除協定（Robots exclusion protocol），也被稱為robots.txt議定書[10]，這份協定是讓管理員指明網路伺服器的不應該爬取的約定。這個標準沒有包括重新存取一台伺服器的間隔的建議，雖然設定存取間隔是避免伺服器超載的最有效辦法。最近的商業搜尋引擎，如Google，Ask Jeeves，MSN和Yahoo可以在robots.txt中使用一個額外的 「Crawl-delay」參數來指明請求之間的延遲。
#
# 一個並列爬蟲是並列執行多個行程的爬蟲。它的目標是最大化下載的速度，同時儘量減少並列的開銷和下載重複的頁面。為了避免下載一個頁面兩次，爬蟲系統需要策略來處理爬蟲執行時新發現的URL，因為同一個URL位址，可能被不同的爬蟲行程抓到。

# %% [markdown]
# ### 範例2：從爬取的文章內容中，擷取出有外部連結的關鍵字。這些關鍵字在文章中是以藍色字體顯示，會連到外部的網頁，並解釋其內容。

# %%
for ext_link in content:
    a_tag = ext_link.find_all('a', href=re.compile("^(/wiki/)((?!;)\S)*$"))
    if len(a_tag) > 0:
        for link_string in a_tag:
            a_link = link_string["href"]       # 外部連結的網址
            a_keyword = link_string.get_text()  # 外部連結的中文名稱
            print("外部連結: [%s] %s" % (a_keyword, a_link))
# Out:
# 外部連結: [全球資訊網] /wiki/%E4%B8%87%E7%BB%B4%E7%BD%91
# 外部連結: [網路機器人] /wiki/%E7%BD%91%E7%BB%9C%E6%9C%BA%E5%99%A8%E4%BA%BA
# 外部連結: [網路] /wiki/%E7%BD%91%E7%BB%9C%E6%90%9C%E7%B4%A2%E5%BC%95%E6%93%8E
# 外部連結: [搜尋引擎] /wiki/%E6%90%9C%E7%B4%A2%E5%BC%95%E6%93%8E
# 外部連結: [robots.txt] /wiki/Robots.txt
# 外部連結: [網站] /wiki/%E7%BD%91%E7%AB%99
# 外部連結: [超連結] /wiki/%E8%B6%85%E9%80%A3%E7%B5%90
# 外部連結: [HTML] /wiki/HTML
# 外部連結: [網頁] /wiki/%E7%B6%B2%E9%A0%81
# 外部連結: [網際網路] /wiki/%E4%BA%92%E8%81%94%E7%BD%91
# 外部連結: [伺服器] /wiki/%E6%9C%8D%E5%8A%A1%E5%99%A8
# 外部連結: [超文字傳輸協定] /wiki/%E8%B6%85%E6%96%87%E6%9C%AC%E5%82%B3%E8%BC%B8%E5%8D%94%E5%AE%9A

# %% [markdown]
# ## 作業：接下來定義一個爬蟲函數，這個函數的主要工作為：
# ### (1) 爬取當前關鍵字的解釋，並存入檔案(因為文章內容太多會佔滿整個頁面，所以存程檔案，方便後續檢視)
# ### (2) 萃取出當前關鍵字所引用的外部連結，當作新的查詢關鍵字
# ### (3) 把第(2)擷取到的關鍵字當作新的關鍵字，回到第(1)步，爬取新的關鍵字解釋。

# %%
def WikiArticle(key_word_link, key_word, recursive):
    
    if (recursive <= max_recursive_depth):
        print("遞迴層[%d] - %s (%s)" % (recursive, key_word_link, key_word))
        
        # 模擬封包的標頭
        headers = {
            'authority': 'zh.wikipedia.org',
            'method': 'GET',
            'path': '/wiki/' + key_word_link,
            'scheme': 'https',
            'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3',
            'accept-encoding': 'gzip, deflate, br',
            'accept-language': 'zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7,zh-CN;q=0.6',
            'cookie': 'GeoIP=TW:TPE:Taipei:25.05:121.53:v4; TBLkisOn=0; mwPhp7Seed=8b8; WMF-Last-Access-Global=04-Jun-2019; WMF-Last-Access=04-Jun-2019',
            'dnt': '1',
            #'if-modified-since': 'Tue, 04 Jun 2019 12:03:22 GMT',
            'referer': 'https://zh.wikipedia.org/wiki/Wikipedia:%E9%A6%96%E9%A1%B5',
            'upgrade-insecure-requests': '1',
            'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Safari/537.36'
        }    

        url = 'https://zh.wikipedia.org' + key_word_link  # 組合關鍵字查詢URL
        resp = requests.get(url, headers=headers)
        resp.encoding = 'utf-8'

        html = BeautifulSoup(resp.text, "lxml")
        content = html.find(name='div', attrs={'id':'mw-content-text'}).find_all(name='p')


            
        #
        # Part 1: 請參考範例1，爬取當前關鍵字的文章內容。
        #         因為內容太多，我們把它寫入檔案，並以關鍵字作為檔案名稱，以便稍後查閱內容。
        #         請先建立一個名為"WikiArticle"的資料夾，爬取到的文章內容會放在這個資料夾底下。
        #
        '''
        
        Your code here
        
        '''
        import os
        # 決定要儲存的資料夾
        output_dir = 'WikiArticle'
        # 假如資料夾不存在就新增一個資料夾
        if not os.path.exists(output_dir):
            os.makedirs(output_dir)
        for paragraph in content:  
            file_name = key_word.replace('/', '_')  # 以'_'取代'/', 避免檔名被誤解釋成路徑
            f = open(output_dir + "/" + file_name, "a+", encoding='utf-8')
            f.write( str(paragraph.get_text()) + "\n" )
            f.close()
        
        #
        # Part 2: 請參考範例2，萃取出本篇文章中所延伸引用的外部連結，並儲存在external_link_dict
        #
        external_link_dict = dict({})
        '''
        
        Your code here
        
        '''
        for ext_link in content:
            a_tag = ext_link.find_all('a', href=re.compile("^(/wiki/)((?!;)\S)*$"))
            if len(a_tag) > 0:
                for link_string in a_tag:
                    a_link = link_string["href"]       # 外部連結的網址
                    a_keyword = link_string.get_text()  # 外部連結的中文名稱
                    print("外部連結: %s [%s]" % (a_link, a_keyword))
                    external_link_dict[a_link] = a_keyword
                    
        #
        # Part 3: 將Part 2所收集的外部連結，當作新的關鍵字，繼續迭代深入爬蟲
        #
        if (len(external_link_dict) > 0):
            
            recursive = recursive + 1  # 遞迴深度加1
            
            for k, v in external_link_dict.items():
                WikiArticle(k, v, recursive)  # 再次呼叫同樣的函數，執行同樣的流程

# %% [markdown]
# ### 執行前個步驟定義好的爬蟲主程式

# %%
# 定義爬取的遞迴深度。深度不要訂太深，否則會爬很久。
max_recursive_depth = 2

WikiArticle(root_keyword_link, input_keyword, 0)
# Out:
# 遞迴層[0] - /wiki/%E7%B6%B2%E8%B7%AF%E7%88%AC%E8%9F%B2 (網路爬蟲)
# 外部連結: /wiki/%E4%B8%87%E7%BB%B4%E7%BD%91 [全球資訊網]
# 外部連結: /wiki/%E7%BD%91%E7%BB%9C%E6%9C%BA%E5%99%A8%E4%BA%BA [網路機器人]
# 外部連結: /wiki/%E7%BD%91%E7%BB%9C%E6%90%9C%E7%B4%A2%E5%BC%95%E6%93%8E [網路]
# 外部連結: /wiki/%E6%90%9C%E7%B4%A2%E5%BC%95%E6%93%8E [搜尋引擎]
# 外部連結: /wiki/Robots.txt [robots.txt]
# 外部連結: /wiki/%E7%BD%91%E7%AB%99 [網站]
# 外部連結: /wiki/%E8%B6%85%E9%80%A3%E7%B5%90 [超連結]
# 外部連結: /wiki/HTML [HTML]
# 外部連結: /wiki/%E7%B6%B2%E9%A0%81 [網頁]
# 外部連結: /wiki/%E4%BA%92%E8%81%94%E7%BD%91 [網際網路]
# 外部連結: /wiki/%E6%9C%8D%E5%8A%A1%E5%99%A8 [伺服器]
# 外部連結: /wiki/%E8%B6%85%E6%96%87%E6%9C%AC%E5%82%B3%E8%BC%B8%E5%8D%94%E5%AE%9A [超文字傳輸協定]
# 遞迴層[1] - /wiki/%E4%B8%87%E7%BB%B4%E7%BD%91 (全球資訊網)
# 外部連結: /wiki/%E4%BA%92%E8%81%94%E7%BD%91 [網際網路]
# 外部連結: /wiki/%E8%B6%85%E6%96%87%E6%9C%AC [超文字]
# 外部連結: /wiki/%E8%92%82%E5%A7%86%C2%B7%E4%BC%AF%E7%BA%B3%E6%96%AF-%E6%9D%8E [提姆·柏內茲-李]
# 外部連結: /wiki/CERN [CERN]
# 外部連結: /wiki/%E7%B6%B2%E9%A0%81%E7%80%8F%E8%A6%BD%E5%99%A8 [網頁瀏覽器]
# 外部連結: /wiki/%E8%B3%87%E8%A8%8A%E6%99%82%E4%BB%A3 [資訊時代]
# 外部連結: /wiki/%E7%B6%B2%E9%A0%81 [網頁]
# 外部連結: /wiki/%E6%A0%BC%E5%BC%8F%E5%8C%96%E6%96%87%E6%9C%AC [格式化]
# 外部連結: /wiki/%E8%B6%85%E6%96%87%E4%BB%B6%E6%A8%99%E7%A4%BA%E8%AA%9E%E8%A8%80 [超文件標示語言]
# 外部連結: /wiki/%E5%9C%96%E7%89%87 [圖片]
# 外部連結: /wiki/%E5%BD%B1%E7%89%87 [影片]
# 外部連結: /wiki/%E8%81%B2%E9%9F%B3 [聲音]
# 外部連結: /wiki/%E5%A4%9A%E5%AA%92%E9%AB%94 [多媒體]
# 外部連結: /wiki/%E7%B6%B2%E9%9A%9B%E7%B6%B2%E8%B7%AF [網際網路]
# 外部連結: /wiki/%E8%92%82%E5%A7%86%C2%B7%E4%BC%AF%E7%BA%B3%E6%96%AF-%E6%9D%8E [提姆·柏內茲-李]
# 外部連結: /wiki/ENQUIRE [ENQUIRE]
# 外部連結: /wiki/%E6%95%B0%E6%8D%AE%E5%BA%93 [資料庫]
# 外部連結: /wiki/%E8%AF%AD%E4%B9%89%E7%BD%91 [語意網]
# 外部連結: /wiki/%E7%BD%97%E4%BC%AF%E7%89%B9%C2%B7%E5%8D%A1%E9%87%8C%E5%A5%A5 [羅伯特·卡里奧]
# 外部連結: /wiki/NeXT [NeXT]
# 外部連結: /wiki/%E8%81%96%E8%AA%95%E7%AF%80 [聖誕節]
# 外部連結: /wiki/%E7%B6%B2%E9%A0%81%E7%80%8F%E8%A6%BD%E5%99%A8 [網頁瀏覽器]
# 外部連結: /wiki/WorldWideWeb [WorldWideWeb]
# 外部連結: /wiki/%E7%B6%B2%E9%A0%81%E4%BC%BA%E6%9C%8D%E5%99%A8 [網頁伺服器]
# 外部連結: /wiki/%E6%96%B0%E9%97%BB%E7%BB%84 [新聞群組]
# 外部連結: /wiki/%E8%B6%85%E6%96%87%E6%9C%AC [超文字]
# 外部連結: /wiki/%E6%B3%B0%E5%BE%B7%C2%B7%E5%B0%BC%E7%88%BE%E6%A3%AE [泰德·尼爾森]
# 外部連結: /wiki/%E9%81%93%E6%A0%BC%E6%8B%89%E6%96%AF%C2%B7%E8%8B%B1%E6%A0%BC%E5%B7%B4%E7%89%B9 [道格拉斯·英格巴特]
# 外部連結: /wiki/%E4%B8%87%E5%B0%BC%E7%93%A6%E5%B0%94%C2%B7%E5%B8%83%E4%BB%80 [萬尼瓦爾·布希]
# 外部連結: /wiki/%E5%BE%AE%E7%BC%A9%E8%83%B6%E7%89%87 [微縮膠片]
# 外部連結: /wiki/%E4%B8%80%E5%8D%83%E9%9B%B6%E4%B8%80%E7%B6%B2%EF%BC%9A%E7%B6%B2%E9%9A%9B%E7%B6%B2%E8%B7%AFWWW%E7%99%BC%E6%98%8E%E4%BA%BA%E7%9A%84%E6%80%9D%E6%83%B3%E6%A7%8B%E5%9C%96 [一千零一網]
# 外部連結: /wiki/HyperCard [HyperCard]
# 外部連結: /wiki/%E6%AD%90%E6%B4%B2%E6%A0%B8%E5%AD%90%E7%A0%94%E7%A9%B6%E7%B5%84%E7%B9%94 [歐洲核子研究組織]
# 外部連結: /wiki/Gopher_(%E7%BD%91%E7%BB%9C%E5%8D%8F%E8%AE%AE) [Gopher]
# 外部連結: /wiki/Unix [Unix]
# 外部連結: /wiki/X_Windows [X Windows]
# 外部連結: /wiki/ViolaWWW [ViolaWWW]
# 外部連結: /wiki/Mosaic [Mosaic]
# 外部連結: /wiki/%E4%BC%8A%E5%88%A9%E8%AB%BE%E5%A4%A7%E5%AD%B8%E5%8E%84%E5%B7%B4%E7%B4%8D-%E9%A6%99%E6%AA%B3%E5%88%86%E6%A0%A1 [伊利諾大學厄巴納-香檳分校]
# 外部連結: /wiki/%E5%9B%BD%E5%AE%B6%E8%B6%85%E7%BA%A7%E7%94%B5%E8%84%91%E5%BA%94%E7%94%A8%E4%B8%AD%E5%BF%83 [國家超級電腦應用中心]
# 外部連結: /wiki/%E9%A9%AC%E5%85%8B%C2%B7%E5%AE%89%E5%BE%B7%E6%A3%AE [馬克·安德森]
# 外部連結: /wiki/%E8%89%BE%E7%88%BE%C2%B7%E9%AB%98%E7%88%BE [艾爾·高爾]
# 外部連結: /wiki/Gopher_(%E7%BD%91%E7%BB%9C%E5%8D%8F%E8%AE%AE) [Gopher]
# 外部連結: /wiki/%E4%B8%87%E7%BB%B4%E7%BD%91%E8%81%94%E7%9B%9F [全球資訊網協會]
# 外部連結: /wiki/%E9%BA%BB%E7%9C%81%E7%90%86%E5%B7%A5%E5%AD%A6%E9%99%A2 [麻省理工學院]
# 外部連結: /wiki/%E8%92%82%E5%A7%86%C2%B7%E4%BC%AF%E7%BA%B3%E6%96%AF-%E6%9D%8E [提姆·柏內茲-李]
# 外部連結: /wiki/%E6%A8%99%E8%A8%98%E5%BC%8F%E8%AA%9E%E8%A8%80 [標記式語言]
# 外部連結: /wiki/%E8%AA%9E%E7%BE%A9%E7%B6%B2 [語義網]
# 外部連結: /wiki/%E5%90%8C%E4%B9%89%E8%AF%8D [同義詞]
# 外部連結: /wiki/TCP/IP [TCP/IP]
# 外部連結: /wiki/HTTP [HTTP]
# 外部連結: /wiki/%E7%94%B5%E8%84%91%E7%BD%91%E7%BB%9C [電腦網路]
# 外部連結: /wiki/HTTP [HTTP]
# 外部連結: /wiki/HTTPS [HTTPS]
# 外部連結: /wiki/%E7%BB%9F%E4%B8%80%E8%B5%84%E6%BA%90%E5%AE%9A%E4%BD%8D%E7%AC%A6 [統一資源定位符]
# 外部連結: /wiki/%E5%9F%9F%E5%90%8D%E7%B3%BB%E7%BB%9F [域名系統]
# 外部連結: /wiki/IP%E5%9C%B0%E5%9D%80 [IP位址]
# 外部連結: /wiki/%E5%A4%A7%E7%9C%BE%E5%82%B3%E5%AA%92 [大眾傳媒]
# 外部連結: /wiki/%E5%87%BA%E7%89%88%E5%95%86 [出版商]
# 外部連結: /wiki/%E5%8F%91%E8%BE%BE%E5%9B%BD%E5%AE%B6 [已開發國家]
# 外部連結: /wiki/%E9%98%BF%E6%8B%89%E4%BC%AF%E8%AF%AD [阿拉伯語]
# 外部連結: /wiki/%E5%B8%8C%E4%BC%AF%E6%9D%A5%E8%AF%AD [希伯來語]
# 外部連結: /wiki/%E6%9C%8D%E5%8A%A1%E5%99%A8 [伺服器]
# 外部連結: /wiki/%E4%B8%AA%E4%BA%BA%E4%B8%BB%E9%A1%B5 [個人首頁]
# 外部連結: /wiki/JavaScript [JavaScript]
# 外部連結: /wiki/ECMAScript [ECMAScript]
# 外部連結: /wiki/Netscape [網景通訊公司]
# 外部連結: /wiki/Java [Java]
# 外部連結: /wiki/%E6%98%87%E9%99%BD%E9%9B%BB%E8%85%A6 [昇陽電腦公司]
# 外部連結: /wiki/C%E8%AF%AD%E8%A8%80 [C語言]
# 外部連結: /wiki/C%2B%2B [C++]
# 外部連結: /wiki/%E9%9D%A2%E5%90%91%E5%AF%B9%E8%B1%A1%E7%9A%84%E7%A8%8B%E5%BA%8F%E8%AE%BE%E8%AE%A1 [物件導向的程式設計]
# 外部連結: /wiki/C%2B%2B [C++]
# 外部連結: /wiki/%E6%96%87%E6%A1%A3%E5%AF%B9%E8%B1%A1%E6%A8%A1%E5%9E%8B [文件物件模型]
# 外部連結: /wiki/DHTML [DHTML]
# 外部連結: /wiki/%E9%A7%9D%E5%B3%B0%E5%BC%8F%E5%A4%A7%E5%B0%8F%E5%AF%AB [駝峰式大小寫]
# 外部連結: /wiki/%E5%8C%97%E7%BE%8E [北美]
# 外部連結: /wiki/%E6%9D%8E%E5%B0%8F%E6%96%87 [李小文]
# 外部連結: /wiki/%E4%B8%AD%E5%9B%BD%E7%A7%91%E5%AD%A6%E9%99%A2%E9%99%A2%E5%A3%AB [中國科學院院士]
# 外部連結: /wiki/%E4%B8%AD%E5%9C%8B%E6%96%B0%E8%81%9E%E9%9B%BB%E8%85%A6%E7%B6%B2%E7%B5%A1 [中國新聞電腦網路]
# 外部連結: /wiki/%E8%8F%AF%E5%A4%8F%E6%96%87%E6%91%98 [華夏文摘]
# 外部連結: /wiki/%E6%BC%A2%E8%AA%9E%E6%8B%BC%E9%9F%B3 [漢語拼音]
# 外部連結: /wiki/%E6%A0%87%E5%87%86 [標準]
# 外部連結: /wiki/%E4%B8%87%E7%BB%B4%E7%BD%91%E8%81%94%E7%9B%9F [全球資訊網協會]
# 外部連結: /wiki/%E6%B7%B1%E7%BD%91 [深網]
# 外部連結: /wiki/%E7%BD%91%E9%A1%B5 [網頁]
# 外部連結: /wiki/%E8%8B%B1%E8%AF%AD [英語]
# 外部連結: /wiki/%E5%BE%B7%E8%AF%AD [德語]
# 外部連結: /wiki/%E6%B3%95%E8%AF%AD [法語]
# 外部連結: /wiki/%E6%97%A5%E8%AF%AD [日語]
# 外部連結: /wiki/%E4%B8%AD%E6%96%87 [中文]
# 外部連結: /wiki/%E8%AF%AD%E8%A8%80 [語言]
# 外部連結: /wiki/%E5%9B%A0%E7%89%B9%E7%BD%91 [網際網路]
# 外部連結: /wiki/%E9%BB%9E%E5%B0%8D%E9%BB%9E%E6%8A%80%E8%A1%93 [點對點技術]
# 外部連結: /wiki/QoS [服務品質]
# 外部連結: /wiki/Google [Google]
# 外部連結: /wiki/Google_doodle [Google doodle]
# 遞迴層[2] - /wiki/%E4%BA%92%E8%81%94%E7%BD%91 (網際網路)
# 外部連結: /wiki/20%E4%B8%96%E7%B4%80 [20世紀]
# 外部連結: /wiki/%E7%94%B5%E8%84%91%E7%BD%91%E7%BB%9C [電腦網路]
# 外部連結: /wiki/%E7%B6%B2%E8%B7%AF [網路]
# 外部連結: /wiki/%E7%BD%91%E7%BB%9C%E5%8D%8F%E8%AE%AE [網路協定]
# 外部連結: /wiki/%E5%AD%B8%E8%A1%93%E7%95%8C [學術界]
# 外部連結: /wiki/%E7%94%B5%E5%AD%90%E6%8A%80%E6%9C%AF [電子]
# 外部連結: /wiki/%E7%84%A1%E7%B7%9A [無線]
# 外部連結: /wiki/%E5%85%89%E7%BA%96%E7%B6%B2%E8%B7%AF [光纖網路技術]
# 外部連結: /wiki/%E8%B6%85%E6%96%87%E6%9C%AC [超文字]
# 外部連結: /wiki/%E8%90%AC%E7%B6%AD%E7%B6%B2 [全球資訊網]
# 外部連結: /wiki/%E9%9B%BB%E5%AD%90%E9%83%B5%E4%BB%B6 [電子郵件]
# 外部連結: /wiki/%E7%B6%B2%E9%9A%9B%E5%8D%94%E8%AD%B0%E9%80%9A%E8%A9%B1%E6%8A%80%E8%A1%93 [通話]
# 外部連結: /wiki/%E6%AA%94%E6%A1%88%E5%88%86%E4%BA%AB [檔案分享]
# 外部連結: /wiki/%E7%BE%8E%E5%9C%8B%E8%81%AF%E9%82%A6%E6%94%BF%E5%BA%9C [美國聯邦政府]
# 外部連結: /wiki/ARPANET [ARPANET]
# 外部連結: /wiki/TCP/IP [TCP/IP]
# 外部連結: /wiki/%E5%88%86%E6%95%A3%E7%BD%91%E7%BB%9C [分散網路]
# 外部連結: /wiki/%E6%8E%92%E9%98%9F%E8%AE%BA [排隊論]
# 外部連結: /wiki/%E5%B0%81%E5%8C%85%E4%BA%A4%E6%8F%9B [封包交換]
# 外部連結: /wiki/%E7%BE%8E%E5%9B%BD%E5%9B%BD%E9%98%B2%E9%83%A8 [美國國防部]
# 外部連結: /wiki/%E5%9C%8B%E9%98%B2%E9%AB%98%E7%AD%89%E7%A0%94%E7%A9%B6%E8%A8%88%E5%8A%83%E7%BD%B2 [高等研究計劃署]
# 外部連結: /wiki/%E5%86%B7%E6%88%98 [冷戰]
# 外部連結: /wiki/ARPANET [ARPANET]
# 外部連結: /wiki/%E4%BC%A6%E7%BA%B3%E5%BE%B7%C2%B7%E5%85%8B%E8%8E%B1%E5%9B%A0%E7%BD%97%E5%85%8B [倫納德·克萊因羅克]
# 外部連結: /wiki/%E5%8A%A0%E5%88%A9%E7%A6%8F%E5%B0%BC%E4%BA%9E%E5%A4%A7%E5%AD%B8%E6%B4%9B%E6%9D%89%E7%A3%AF%E5%88%86%E6%A0%A1 [加利福尼亞大學洛杉磯分校]
# 外部連結: /wiki/%E9%97%A8%E6%B4%9B%E5%B8%95%E5%85%8B_(%E5%8A%A0%E5%88%A9%E7%A6%8F%E5%B0%BC%E4%BA%9A%E5%B7%9E) [加利福尼亞州門羅帕克]
# 外部連結: /wiki/%E9%81%93%E6%A0%BC%E6%8B%89%E6%96%AF%C2%B7%E6%81%A9%E6%A0%BC%E5%B0%94%E5%B7%B4%E7%89%B9 [道格拉斯·恩格爾巴特]
# 外部連結: /wiki/%E5%8A%A0%E5%88%A9%E7%A6%8F%E5%B0%BC%E4%BA%9E%E5%A4%A7%E5%AD%B8%E8%81%96%E5%A1%94%E8%8A%AD%E8%8A%AD%E6%8B%89%E5%88%86%E6%A0%A1 [加利福尼亞大學聖塔芭芭拉分校]
# 外部連結: /wiki/%E7%8A%B9%E4%BB%96%E5%A4%A7%E5%AD%A6 [猶他大學]
# 外部連結: /wiki/%E7%BD%97%E4%BC%AF%E7%89%B9%C2%B7%E5%8D%A1%E6%81%A9 [羅伯特·卡恩]
# 外部連結: /wiki/%E6%96%87%E9%A0%93%C2%B7%E7%91%9F%E5%A4%AB [文頓·瑟夫]
# 外部連結: /wiki/TCP/IP [TCP/IP]
# 外部連結: /wiki/%E5%9B%BE%E7%81%B5%E5%A5%96 [圖靈獎]
# 外部連結: /wiki/%E7%BE%8E%E5%9B%BD%E5%9B%BD%E5%AE%B6%E7%A7%91%E5%AD%A6%E5%9F%BA%E9%87%91%E4%BC%9A [美國國家科學基金會]
# 外部連結: /wiki/%E8%B6%85%E7%B4%9A%E9%9B%BB%E8%85%A6 [超級電腦]
# 外部連結: /wiki/%E4%BA%92%E8%81%AF%E7%B6%B2%E6%9C%8D%E5%8B%99%E6%8F%90%E4%BE%9B%E5%95%86 [網際網路服務提供商]
# 外部連結: /wiki/CompuServe [CompuServe]
# 外部連結: /wiki/%E5%BA%B7%E5%A5%88%E5%B0%94%E5%A4%A7%E5%AD%A6 [康奈爾大學]
# 外部連結: /wiki/%E6%AD%90%E6%B4%B2%E6%A0%B8%E5%AD%90%E7%A0%94%E7%A9%B6%E4%B8%AD%E5%BF%83 [歐洲核子研究中心]
# 外部連結: /wiki/%E8%92%82%E5%A7%86%C2%B7%E4%BC%AF%E7%BA%B3%E6%96%AF-%E6%9D%8E [提姆·柏內茲-李]
# 外部連結: /wiki/WorldWideWeb [第一個網頁瀏覽器]
# 外部連結: /wiki/%E4%B8%87%E7%BB%B4%E7%BD%91 [全球資訊網]
# 外部連結: /wiki/%E8%B6%85%E6%96%87%E6%9C%AC%E5%82%B3%E8%BC%B8%E5%8D%94%E5%AE%9A [超文字傳輸協定]
# 外部連結: /wiki/%E8%B6%85%E6%96%87%E6%9C%AC%E6%A0%87%E8%AE%B0%E8%AF%AD%E8%A8%80 [超文字標記語言]
# 外部連結: /wiki/%E7%B6%B2%E9%A0%81%E7%80%8F%E8%A6%BD%E5%99%A8 [網頁瀏覽器]
# 外部連結: /wiki/%E7%B6%B2%E9%A0%81%E4%BC%BA%E6%9C%8D%E5%99%A8 [網頁伺服器]
# 外部連結: /wiki/%E7%B6%B2%E7%AB%99 [網站]
# 外部連結: /wiki/ARPANET [ARPANET]
# 外部連結: /wiki/%E7%BE%8E%E8%81%94%E7%A4%BE [美聯社]
# 外部連結: /wiki/%E4%B8%87%E7%BB%B4%E7%BD%91 [web]
# 外部連結: /wiki/%E7%BA%BD%E7%BA%A6%E6%97%B6%E6%8A%A5 [紐約時報]
# 外部連結: /wiki/%E6%92%A5%E8%99%9F%E9%80%A3%E7%B7%9A [電話撥號]
# 外部連結: /wiki/%E7%B6%B2%E9%9A%9B%E7%B6%B2%E8%B7%AF%E5%8D%94%E5%AE%9A [網際網路協定]
# 外部連結: /wiki/IPv4 [IPv4]
# 外部連結: /wiki/IP%E5%9C%B0%E5%9D%80 [IP位址]
# 外部連結: /wiki/IPv6 [IPv6]
# 外部連結: /wiki/%E7%94%A8%E6%88%B7%E6%95%B0%E6%8D%AE%E6%8A%A5%E5%8D%8F%E8%AE%AE [UDP協定]
# 外部連結: /wiki/%E4%BC%A0%E8%BE%93%E6%8E%A7%E5%88%B6%E5%8D%8F%E8%AE%AE [TCP協定]
# 外部連結: /wiki/UDP [UDP]
# 外部連結: /wiki/%E6%96%87%E4%BB%B6%E4%BC%A0%E8%BE%93%E5%8D%8F%E8%AE%AE [FTP]
# 外部連結: /wiki/%E8%B6%85%E6%96%87%E6%9C%AC%E4%BC%A0%E8%BE%93%E5%8D%8F%E8%AE%AE [HTTP]
# 外部連結: /wiki/%E5%85%A8%E7%90%83%E8%B3%87%E8%A8%8A%E7%B6%B2 [全球資訊網]
# 外部連結: /wiki/%E7%A4%BE%E7%BE%A4%E5%AA%92%E9%AB%94 [社群媒體]
# 外部連結: /wiki/%E9%9B%BB%E5%AD%90%E9%83%B5%E4%BB%B6 [電子郵件]
# 外部連結: /wiki/%E8%A1%8C%E5%8B%95%E6%87%89%E7%94%A8%E7%A8%8B%E5%BC%8F [行動應用程式]
# 外部連結: /wiki/%E5%A4%9A%E4%BA%BA%E7%94%B5%E5%AD%90%E6%B8%B8%E6%88%8F [多人電子遊戲]
# 外部連結: /wiki/VoIP [網際網路通話]
# 外部連結: /wiki/%E6%AA%94%E6%A1%88%E5%88%86%E4%BA%AB [檔案分享]
# 外部連結: /wiki/%E4%B8%B2%E6%B5%81%E5%AA%92%E9%AB%94 [串流媒體]
# 外部連結: /wiki/%E4%BC%BA%E6%9C%8D%E5%99%A8 [伺服器]
# 外部連結: /wiki/%E8%B3%87%E6%96%99%E4%B8%AD%E5%BF%83 [資料中心]
# 外部連結: /wiki/%E5%85%A7%E5%AE%B9%E5%82%B3%E9%81%9E%E7%B6%B2%E8%B7%AF [內容傳遞網路]
# 外部連結: /wiki/%E5%85%A8%E7%90%83%E8%B3%87%E8%A8%8A%E7%B6%B2 [全球資訊網]
# 外部連結: /wiki/%E9%9B%BB%E8%85%A6%E6%AA%94%E6%A1%88 [檔案]
# 外部連結: /wiki/%E5%9C%96%E7%89%87 [圖片]
# 外部連結: /wiki/%E5%A4%9A%E5%AA%92%E9%AB%94 [多媒體]
# 外部連結: /wiki/%E8%B6%85%E9%80%A3%E7%B5%90 [超連結]
# 外部連結: /wiki/%E7%B5%B1%E4%B8%80%E8%B3%87%E6%BA%90%E6%A8%99%E8%AA%8C%E7%AC%A6 [統一資源標誌符]
# 外部連結: /wiki/%E7%B6%B2%E9%A0%81%E4%BC%BA%E6%9C%8D%E5%99%A8 [網頁伺服器]
# 外部連結: /wiki/%E8%B6%85%E6%96%87%E6%9C%AC%E5%82%B3%E8%BC%B8%E5%8D%94%E8%AD%B0 [超文字傳輸協定]
# 外部連結: /wiki/%E5%BE%AE%E8%BB%9F [微軟]
# 外部連結: /wiki/Internet_Explorer [Internet Explorer]
# 外部連結: /wiki/Microsoft_Edge [Edge]
# 外部連結: /wiki/Mozilla_Firefox [Mozilla Firefox]
# 外部連結: /wiki/Opera%E9%9B%BB%E8%85%A6%E7%80%8F%E8%A6%BD%E5%99%A8 [Opera]
# 外部連結: /wiki/%E8%98%8B%E6%9E%9C%E5%85%AC%E5%8F%B8 [蘋果公司]
# 外部連結: /wiki/Safari [Safari]
# 外部連結: /wiki/Google_Chrome [Google Chrome]
# 外部連結: /wiki/%E5%A4%9A%E5%AA%92%E9%AB%94 [多媒體]
# 外部連結: /wiki/%E7%BD%91%E9%A1%B5%E6%B8%B8%E6%88%8F [遊戲]
# 外部連結: /wiki/Yahoo [Yahoo]
# 外部連結: /wiki/Bing [Bing]
# 外部連結: /wiki/Google [Google]
# 外部連結: /wiki/%E6%90%9C%E5%B0%8B%E5%BC%95%E6%93%8E [搜尋引擎]
# 外部連結: /wiki/%E9%97%9C%E9%8D%B5%E5%AD%97 [關鍵字]
# 外部連結: /wiki/%E9%9B%BB%E5%AD%90%E9%83%B5%E4%BB%B6 [電子郵件]
# 外部連結: /wiki/%E9%9B%BB%E5%AD%90%E9%83%B5%E4%BB%B6%E5%9C%B0%E5%9D%80 [電子郵件位址]
# 外部連結: /wiki/%E6%AA%94%E6%A1%88%E5%88%86%E4%BA%AB [檔案分享]
# 外部連結: /wiki/%E6%AA%94%E6%A1%88%E5%82%B3%E8%BC%B8%E5%8D%94%E5%AE%9A [檔案傳輸協定]
# 外部連結: /wiki/%E6%AA%94%E6%A1%88%E4%BC%BA%E6%9C%8D%E5%99%A8 [檔案伺服器]
# 外部連結: /wiki/%E6%83%A1%E6%84%8F%E8%BB%9F%E9%AB%94 [惡意軟體]
# 外部連結: /wiki/%E9%9B%BB%E8%85%A6%E7%97%85%E6%AF%92 [電腦病毒]
# 外部連結: /wiki/%E9%9B%BB%E8%85%A6%E8%A0%95%E8%9F%B2 [電腦蠕蟲]
# 外部連結: /wiki/%E9%98%BB%E6%96%B7%E6%9C%8D%E5%8B%99%E6%94%BB%E6%93%8A [阻斷服務攻擊]
# 外部連結: /wiki/%E5%8B%92%E7%B4%A2%E8%BB%9F%E9%AB%94 [勒索軟體]
# 外部連結: /wiki/%E6%AE%AD%E5%B1%8D%E7%B6%B2%E7%B5%A1 [殭屍網路]
# 外部連結: /wiki/%E9%96%93%E8%AB%9C%E8%BB%9F%E4%BB%B6 [間諜軟體]
# 外部連結: /wiki/%E7%94%B5%E8%84%91%E7%8A%AF%E7%BD%AA [網路犯罪]
# 外部連結: /wiki/%E7%BE%8E%E5%9C%8B%E5%9C%8B%E5%AE%B6%E5%AE%89%E5%85%A8%E5%B1%80 [美國國家安全域]
# 外部連結: /wiki/%E4%B8%AD%E6%83%85%E5%B1%80 [中情局]
# 外部連結: /wiki/%E7%88%B1%E5%BE%B7%E5%8D%8E%C2%B7%E6%96%AF%E8%AF%BA%E7%99%BB [史諾登]
# 外部連結: /wiki/%E8%A1%9B%E5%A0%B1 [衛報]
# 外部連結: /wiki/%E8%8F%AF%E7%9B%9B%E9%A0%93%E9%83%B5%E5%A0%B1 [華盛頓郵報]
# 外部連結: /wiki/%E4%B8%AD%E5%8D%8E%E4%BA%BA%E6%B0%91%E5%85%B1%E5%92%8C%E5%9B%BD [中華人民共和國]
# 外部連結: /wiki/%E6%B2%99%E7%89%B9%E9%98%BF%E6%8B%89%E4%BC%AF [沙烏地阿拉伯]
# 外部連結: /wiki/%E6%94%BF%E6%B2%BB [政治]
# 外部連結: /wiki/%E5%AE%97%E6%95%99 [宗教]
# 外部連結: /wiki/%E4%BF%A1%E6%81%AF%E6%8A%80%E6%9C%AF [資訊科技]
# 外部連結: /wiki/%E6%9C%9D%E9%B2%9C [朝鮮]
# 外部連結: /wiki/%E5%9C%8B%E5%AE%B6%E5%8D%80%E5%9F%9F%E7%B6%B2%E8%B7%AF [國家區域網路]
# 外部連結: /wiki/%E7%B6%93%E6%BF%9F%E5%90%88%E4%BD%9C%E7%99%BC%E5%B1%95%E7%B5%84%E7%B9%94 [經濟合作發展組織]
# 外部連結: /wiki/%E5%86%B0%E5%B3%B6 [冰島]
# 外部連結: /wiki/%E9%9F%A9%E5%9B%BD [韓國]
# 外部連結: /wiki/%E8%8D%B7%E8%98%AD [荷蘭]
# 外部連結: /wiki/%E4%B8%B9%E9%BA%A5 [丹麥]
# 外部連結: /wiki/%E7%91%9E%E5%A3%AB [瑞士]
# 外部連結: /wiki/%E7%BE%8E%E5%9C%8B [美國]
# 外部連結: /wiki/%E4%B8%AD%E5%9B%BD%E4%BA%92%E8%81%94%E7%BD%91%E7%BB%9C%E4%BF%A1%E6%81%AF%E4%B8%AD%E5%BF%83 [中國互聯網絡信息中心]
# 外部連結: /wiki/%E7%BD%91%E6%B0%91 [網友]
# 遞迴層[2] - /wiki/%E8%B6%85%E6%96%87%E6%9C%AC (超文字)
# 外部連結: /wiki/%E9%9B%BB%E8%85%A6%E9%A1%AF%E7%A4%BA%E5%99%A8 [電腦顯示器]
# 外部連結: /wiki/%E9%9B%BB%E5%AD%90%E8%A8%AD%E5%82%99 [電子裝置]
# 外部連結: /wiki/%E8%B6%85%E9%80%A3%E7%B5%90 [超連結]
# 外部連結: /wiki/%E8%B1%AA%E5%B0%94%E8%B5%AB%C2%B7%E8%B7%AF%E6%98%93%E6%96%AF%C2%B7%E5%8D%9A%E5%B0%94%E8%B5%AB%E6%96%AF [豪爾赫·路易斯·博爾赫斯]
# 外部連結: /wiki/%E5%B0%8F%E5%BE%84%E5%88%86%E5%B2%94%E7%9A%84%E8%8A%B1%E5%9B%AD [小徑分岔的花園]
# 外部連結: /wiki/%E7%9F%AD%E7%AF%87%E5%B0%8F%E8%AA%AA [短篇小說]
# 外部連結: /wiki/%E4%B8%87%E5%B0%BC%E7%93%A6%E5%B0%94%C2%B7%E5%B8%83%E4%BB%80 [萬尼瓦爾·布希]
# 外部連結: /wiki/%E5%85%A8%E7%90%83%E8%B3%87%E8%A8%8A%E7%B6%B2 [全球資訊網]
# 遞迴層[2] - /wiki/%E8%92%82%E5%A7%86%C2%B7%E4%BC%AF%E7%BA%B3%E6%96%AF-%E6%9D%8E (提姆·柏內茲-李)
#

# 外部連結: /wiki/%E8%B6%85%E6%96%87%E6%9C%AC%E7%B3%BB%E7%BB%9F [超文字系統]
# 外部連結: /wiki/ENQUIRE [ENQUIRE]
# 外部連結: /wiki/%E4%BC%AF%E6%81%A9%E8%8C%85%E6%96%AF [伯恩茅斯]
# 外部連結: /wiki/%E8%BF%9C%E7%A8%8B%E8%BF%87%E7%A8%8B%E8%B0%83%E7%94%A8 [遠端程序呼叫]
# 外部連結: /wiki/%E8%AE%A1%E7%AE%97%E6%9C%BA%E7%BD%91%E7%BB%9C [電腦網路]
# 外部連結: /wiki/%E7%BD%91%E9%A1%B5%E6%B5%8F%E8%A7%88%E5%99%A8 [網頁瀏覽器]
# 外部連結: /wiki/WorldWideWeb [WorldWideWeb]
# 外部連結: /wiki/NeXTSTEP [NeXTSTEP]
# 外部連結: /wiki/CERN_httpd [CERN httpd]
# 外部連結: /wiki/%E5%AE%88%E6%8A%A4%E8%BF%9B%E7%A8%8B [守護行程]
# 外部連結: /wiki/%E7%BD%91%E7%AB%99 [網站]
# 外部連結: /wiki/%E4%B8%87%E7%BB%B4%E7%BD%91%E8%81%94%E7%9B%9F [全球資訊網協會]
# 外部連結: /wiki/%E5%8D%97%E5%AE%89%E6%99%AE%E6%95%A6%E5%A4%A7%E5%AD%A6 [南安普敦大學]
# 外部連結: /wiki/%E8%AF%AD%E4%B9%89%E7%BD%91 [語意網]
# 外部連結: /wiki/%E6%B3%B0%E6%99%A4%E5%A3%AB%E6%8A%A5 [泰晤士報]
# 外部連結: /wiki/%E6%88%88%E7%99%BB%C2%B7%E5%B8%83%E6%9C%97 [戈登·布朗]
# 外部連結: /wiki/%E8%8B%B1%E5%9C%8B%E5%9C%B0%E5%BD%A2%E6%B8%AC%E9%87%8F%E5%B1%80 [英國地形測量局]
# 外部連結: /wiki/%E7%BD%91%E7%BB%9C%E4%B8%AD%E7%AB%8B%E6%80%A7 [網路中立性]
# 外部連結: /wiki/%E4%BA%92%E8%81%94%E7%BD%91%E6%9C%8D%E5%8A%A1%E4%BE%9B%E5%BA%94%E5%95%86 [網際網路服務供應商]
# 遞迴層[2] - /wiki/CERN (CERN)
# 外部連結: /wiki/%E6%B3%95%E8%AF%AD [法語]
# 外部連結: /wiki/%E8%8B%B1%E6%96%87 [英文]
# 外部連結: /wiki/%E7%B2%92%E5%AD%90%E7%89%A9%E7%90%86%E5%AD%B8 [粒子物理學]
# 外部連結: /wiki/%E5%85%A8%E7%90%83%E8%B3%87%E8%A8%8A%E7%B6%B2 [全球資訊網]
# 外部連結: /wiki/%E7%91%9E%E5%A3%AB [瑞士]
# 外部連結: /wiki/%E6%97%A5%E5%85%A7%E7%93%A6 [日內瓦]
# 外部連結: /wiki/%E6%B2%BB%E5%A4%96%E6%B3%95%E6%AC%8A [治外法權]
# 外部連結: /wiki/%E4%BB%A5%E8%89%B2%E5%88%97 [以色列]
# 外部連結: /wiki/%E6%AD%90%E6%B4%B2 [歐洲]
# 外部連結: /wiki/%E7%89%A9%E7%90%86%E5%AD%B8 [物理學]
# 外部連結: /wiki/%E7%B2%92%E5%AD%90%E5%8A%A0%E9%80%9F%E5%99%A8 [粒子加速器]
# 外部連結: /wiki/%E7%A7%91%E7%93%A6%E7%88%BE%E6%96%AF%E5%9F%BA [科瓦爾斯基]
# 外部連結: /wiki/%E6%B2%83%E7%B4%8D%C2%B7%E6%B5%B7%E6%A3%AE%E5%A0%A1 [沃納·海森堡]
# 外部連結: /wiki/%E7%B2%92%E5%AD%90%E7%89%A9%E7%90%86%E5%AD%B8 [粒子物理學]
# 外部連結: /wiki/%E5%85%A8%E7%90%83%E8%B3%87%E8%A8%8A%E7%B6%B2 [全球資訊網]
# 外部連結: /wiki/ENQUIRE [詢問計劃]
# 外部連結: /wiki/%E6%8F%90%E5%A7%86%C2%B7%E6%9F%8F%E5%85%A7%E8%8C%B2-%E6%9D%8E [提姆·柏內茲-李]
# 外部連結: /wiki/%E7%BD%97%E4%BC%AF%E7%89%B9%C2%B7%E5%8D%A1%E9%87%8C%E5%A5%A5 [羅伯特·卡里奧]
# 外部連結: /wiki/%E8%B6%85%E6%96%87%E6%9C%AC [超文字]
# 外部連結: /wiki/%E7%B6%B2%E6%A0%BC%E8%A8%88%E7%AE%97 [網格計算]
# 外部連結: /wiki/%E5%A4%A7%E5%9E%8B%E5%BC%B7%E5%AD%90%E5%B0%8D%E6%92%9E%E6%A9%9F [大型強子對撞機]
# 外部連結: /wiki/%E5%A4%A7%E5%9E%8B%E9%9B%BB%E5%AD%90%E6%AD%A3%E5%AD%90%E5%B0%8D%E6%92%9E%E6%A9%9F [大型電子正子對撞機]
# 外部連結: /wiki/%E6%97%A5%E5%86%85%E7%93%A6%E5%9B%BD%E9%99%85%E6%9C%BA%E5%9C%BA [日內瓦國際機場]
# 外部連結: /wiki/%E4%BE%8F%E7%BD%97%E5%B1%B1 [侏羅山]
# 外部連結: /wiki/%E7%B7%8A%E6%B9%8A%E7%B7%B2%E5%AD%90%E7%B7%9A%E5%9C%88 [緊湊緲子線圈]
# 外部連結: /wiki/%E8%B6%85%E7%92%B0%E9%9D%A2%E5%84%80%E5%99%A8 [超環面儀器]
# 外部連結: /wiki/LHCb [LHCb]
# 外部連結: /wiki/%E6%AF%94%E5%88%A9%E6%99%82 [比利時]
# 外部連結: /wiki/%E9%9B%BB%E8%85%A6 [電腦]
# 外部連結: /wiki/%E4%B8%B2%E6%B5%81 [串流]
# 外部連結: /wiki/%E5%A4%A7%E5%9E%8B%E5%BC%B7%E5%AD%90%E5%B0%8D%E6%92%9E%E6%A9%9F [大型強子對撞機]
# 外部連結: /wiki/%E5%AE%89%E7%9C%81 [安省]
# 外部連結: /wiki/%E5%A4%A7%E5%9E%8B%E5%BC%B7%E5%AD%90%E5%B0%8D%E6%92%9E%E6%A9%9F [大型強子對撞機]
# 外部連結: /wiki/%E5%A4%B8%E5%85%8B [魅夸克]
# 外部連結: /wiki/%E5%9C%B0%E7%90%86%E5%9D%90%E6%A0%87 [座標]
# 遞迴層[2] - /wiki/%E7%B6%B2%E9%A0%81%E7%80%8F%E8%A6%BD%E5%99%A8 (網頁瀏覽器)
# 外部連結: /wiki/%E5%85%A8%E7%90%83%E8%B3%87%E8%A8%8A%E7%B6%B2 [全球資訊網]
# 外部連結: /wiki/%E6%87%89%E7%94%A8%E7%A8%8B%E5%BC%8F [應用程式]
# 外部連結: /wiki/%E7%B5%B1%E4%B8%80%E8%B3%87%E6%BA%90%E6%A8%99%E8%AA%8C%E7%AC%A6 [統一資源標誌符]
# 外部連結: /wiki/%E8%B6%85%E9%80%A3%E7%B5%90 [超連結]
# 外部連結: /wiki/%E4%B8%93%E7%94%A8%E7%BD%91%E7%BB%9C [專用網路]
# 外部連結: /wiki/%E7%B6%B2%E9%A0%81%E4%BC%BA%E6%9C%8D%E5%99%A8 [網頁伺服器]
# 外部連結: /wiki/%E6%AA%94%E6%A1%88%E7%B3%BB%E7%B5%B1 [檔案系統]
# 外部連結: /wiki/Mozilla_Firefox [Mozilla Firefox]
# 外部連結: /wiki/Internet_Explorer [Internet Explorer]
# 外部連結: /wiki/Microsoft_Edge [Microsoft Edge]
# 外部連結: /wiki/Google_Chrome [Google Chrome]
# 外部連結: /wiki/Opera%E9%9B%BB%E8%85%A6%E7%80%8F%E8%A6%BD%E5%99%A8 [Opera]
# 外部連結: /wiki/Safari [Safari]
# 外部連結: /wiki/%E6%8F%90%E5%A7%86%C2%B7%E6%9F%8F%E5%85%A7%E8%8C%B2-%E6%9D%8E [提姆·柏內茲-李]
# 外部連結: /wiki/WorldWideWeb [WorldWideWeb]
# 外部連結: /wiki/%E5%A6%AE%E5%8F%AF%E6%8B%89%C2%B7%E4%BD%A9%E6%B4%9B [妮可拉·佩洛]
# 外部連結: /wiki/Line_Mode_Browser [LMB]
# 外部連結: /wiki/%E5%93%91%E7%BB%88%E7%AB%AF [啞終端]
# 外部連結: /wiki/%E9%A9%AC%E5%85%8B%C2%B7%E5%AE%89%E5%BE%B7%E6%A3%AE [馬克·安德森]
# 外部連結: /wiki/Mosaic [Mosaic]
# 外部連結: /wiki/NCSA [NCSA]
# 外部連結: /wiki/Netscape [Netscape]
# 外部連結: /wiki/Netscape_Navigator [Netscape Navigator]
# 外部連結: /wiki/%E5%BE%AE%E8%BB%9F [微軟]
# 外部連結: /wiki/Spyglass%E5%85%AC%E5%8F%B8 [Spyglass公司]
# 外部連結: /wiki/Internet_Explorer [Internet Explorer]
# 外部連結: /wiki/%E6%B5%8F%E8%A7%88%E5%99%A8%E5%A4%A7%E6%88%98 [瀏覽器大戰]
# 外部連結: /wiki/Windows [Windows]
# 外部連結: /wiki/Opera%E9%9B%BB%E8%85%A6%E7%80%8F%E8%A6%BD%E5%99%A8 [Opera]
# 外部連結: /wiki/%E9%96%8B%E6%94%BE%E5%8E%9F%E5%A7%8B%E7%A2%BC [開放原始碼]
# 外部連結: /wiki/Mozilla_Application_Suite [Mozilla Application Suite]
# 外部連結: /wiki/%E7%BE%8E%E5%9C%8B%E7%B7%9A%E4%B8%8A [美國線上]
# 外部連結: /wiki/Mozilla_Firefox [Phoenix]
# 外部連結: /wiki/Macintosh [Macintosh]
# 外部連結: /wiki/Internet_Explorer_for_Mac [Internet Explorer]
# 外部連結: /wiki/Firefox [Firefox]
# 外部連結: /wiki/Safari [Safari]
# 外部連結: /wiki/IPad [iPad]
# 外部連結: /wiki/IPhone [iPhone]
# 外部連結: /wiki/Konqueror [Konqueror]
# 外部連結: /wiki/KHTML [KHTML]
# 外部連結: /wiki/%E6%8E%92%E7%89%88%E5%BC%95%E6%93%8E [排版引擎]
# 外部連結: /wiki/OS_X [OS X]
# 外部連結: /wiki/Google_Chrome [Google Chrome]
# 外部連結: /wiki/%E6%90%9C%E5%B0%8B%E5%BC%95%E6%93%8E [搜尋引擎]
# 外部連結: /wiki/Google [Google]
# 外部連結: /wiki/StatCounter [StatCounter]
# 外部連結: /wiki/%E7%B6%B2%E7%B5%A1%E5%A5%97%E4%BB%B6 [網路套件]
# 外部連結: /wiki/%E5%BC%B9%E5%87%BA%E5%BC%8F%E5%B9%BF%E5%91%8A [彈出式廣告]
# 外部連結: /wiki/HTTPS [HTTPS]
# 外部連結: /wiki/%E8%B6%85%E6%96%87%E6%9C%AC%E4%BC%A0%E8%BE%93%E5%8D%8F%E8%AE%AE [HTTP]
# 外部連結: /wiki/Cookie [Cookie]
# 外部連結: /wiki/%E7%80%8F%E8%A6%BD%E5%99%A8%E6%93%B4%E5%85%85%E5%8A%9F%E8%83%BD [瀏覽器擴充功能]
# 外部連結: /wiki/%E9%9A%90%E7%A7%81%E7%8D%BE [防止廣告聯盟]
# 外部連結: /wiki/%E7%80%8F%E8%A6%BD%E5%99%A8%E6%93%B4%E5%85%85%E5%8A%9F%E8%83%BD [瀏覽器擴充功能]
# 遞迴層[2] - /wiki/%E8%B3%87%E8%A8%8A%E6%99%82%E4%BB%A3 (資訊時代)
# 外部連結: /wiki/%E4%BF%A1%E6%81%AF%E4%BA%A7%E4%B8%9A [資訊工業]
# 外部連結: /wiki/%E9%A9%AC%E5%85%8B%C2%B7%E6%89%8E%E5%85%8B%E4%BC%AF%E6%A0%BC [馬克·祖克柏]
# 外部連結: /wiki/Facebook [Facebook]
# 遞迴層[2] - /wiki/%E7%B6%B2%E9%A0%81 (網頁)
# 外部連結: /wiki/%E5%85%A8%E7%90%83%E8%B3%87%E8%A8%8A%E7%B6%B2 [全球資訊網]
# 外部連結: /wiki/%E7%B6%B2%E9%A0%81%E7%80%8F%E8%A6%BD%E5%99%A8 [網頁瀏覽器]
# 外部連結: /wiki/%E8%AE%A1%E7%AE%97%E6%9C%BA [電腦]
# 外部連結: /wiki/%E8%AE%A1%E7%AE%97%E6%9C%BA [電腦]
# 外部連結: /wiki/%E4%BA%92%E8%81%94%E7%BD%91 [網際網路]
# 外部連結: /wiki/%E7%B6%B2%E5%9D%80 [網址]
# 外部連結: /wiki/URL [URL]
# 外部連結: /wiki/%E7%BD%91%E9%A1%B5%E6%B5%8F%E8%A7%88%E5%99%A8 [網頁瀏覽器]
# 外部連結: /wiki/HTML [HTML]
# 外部連結: /wiki/%E5%9C%96%E5%83%8F [圖像]
# 外部連結: /wiki/%E7%B6%B2%E7%AB%99 [網站]
# 外部連結: /wiki/%E9%A6%96%E9%A0%81 [首頁]
# 外部連結: /wiki/%E6%96%87%E5%AD%97%E7%B7%A8%E8%BC%AF%E5%99%A8 [文字編輯器]
# 外部連結: /wiki/HTML%E7%B7%A8%E8%BC%AF%E5%99%A8 [HTML編輯器]
# 外部連結: /wiki/%E5%85%A8%E7%90%83%E8%B3%87%E8%A8%8A%E7%B6%B2 [全球資訊網]
# 外部連結: /wiki/FTP [FTP]
# 外部連結: /wiki/%E4%B8%8A%E8%BC%89 [上傳]
# 遞迴層[2] - /wiki/%E6%A0%BC%E5%BC%8F%E5%8C%96%E6%96%87%E6%9C%AC (格式化)
# 外部連結: /wiki/%E8%8B%B1%E6%96%87 [英文]
# 外部連結: /wiki/%E7%BA%AF%E6%96%87%E6%9C%AC [純文本]
# 外部連結: /wiki/%E8%B6%85%E9%93%BE%E6%8E%A5 [超連結]
# 外部連結: /wiki/HTML [HTML]
# 外部連結: /wiki/Rich_Text_Format [RTF]
# 外部連結: /wiki/UTF-8 [UTF-8]
# 外部連結: /wiki/%E6%A0%87%E8%AE%B0%E8%AF%AD%E8%A8%80 [標記語言]
# 外部連結: /wiki/Microsoft_Word [Microsoft Word]
# 遞迴層[2] - /wiki/%E8%B6%85%E6%96%87%E4%BB%B6%E6%A8%99%E7%A4%BA%E8%AA%9E%E8%A8%80 (超文件標示語言)
# 外部連結: /wiki/%E7%BD%91%E9%A1%B5 [網頁]
# 外部連結: /wiki/%E6%A0%87%E8%AE%B0%E8%AF%AD%E8%A8%80 [標記語言]
# 外部連結: /wiki/CSS [CSS]
# 外部連結: /wiki/JavaScript [JavaScript]
# 外部連結: /wiki/%E7%BD%91%E9%A1%B5%E6%B5%8F%E8%A7%88%E5%99%A8 [網頁瀏覽器]
# 外部連結: /wiki/%E7%BC%96%E7%A8%8B%E8%AF%AD%E8%A8%80 [程式語言]
# 外部連結: /wiki/HTML%E5%85%83%E7%B4%A0 [HTML元素]
# 外部連結: /wiki/%E8%AF%AD%E4%B9%89 [語意]
# 外部連結: /wiki/%E6%8B%AC%E5%8F%B7 [尖括號]
# 外部連結: /wiki/JavaScript [JavaScript]
# 外部連結: /wiki/%E8%84%9A%E6%9C%AC%E8%AF%AD%E8%A8%80 [手稿語言]
# 外部連結: /wiki/%E5%B1%82%E5%8F%A0%E6%A0%B7%E5%BC%8F%E8%A1%A8 [階層式樣式表]
# 外部連結: /wiki/%E4%B8%87%E7%BB%B4%E7%BD%91%E8%81%94%E7%9B%9F [全球資訊網協會]
# 外部連結: /wiki/%E8%92%82%E5%A7%86%C2%B7%E4%BC%AF%E7%BA%B3%E6%96%AF-%E6%9D%8E [提姆·柏內茲-李]
# 外部連結: /wiki/%E6%AD%90%E6%B4%B2%E6%A0%B8%E5%AD%90%E7%A0%94%E7%A9%B6%E7%B5%84%E7%B9%94 [歐洲核子研究中心]
# 外部連結: /wiki/ENQUIRE [ENQUIRE]
# 外部連結: /wiki/%E4%BA%92%E8%81%94%E7%BD%91 [網際網路]
# 外部連結: /wiki/%E8%B6%85%E6%96%87%E6%9C%AC [超文字]
# 外部連結: /wiki/%E7%BD%97%E4%BC%AF%E7%89%B9%C2%B7%E5%8D%A1%E9%87%8C%E5%A5%A5 [羅伯特·卡里奧]
# 外部連結: /wiki/SGML [標準通用標記語言]
# 外部連結: /wiki/%E4%BA%92%E8%81%94%E7%BD%91%E5%B7%A5%E7%A8%8B%E4%BB%BB%E5%8A%A1%E7%BB%84 [網際網路工程任務組]
# 外部連結: /wiki/%E6%96%87%E4%BB%B6%E7%B1%BB%E5%9E%8B%E6%8F%8F%E8%BF%B0 [文件類型定義]
# 外部連結: /wiki/NCSA_Mosaic [NCSA Mosaic]
# 外部連結: /wiki/%E4%B8%87%E7%BB%B4%E7%BD%91%E8%81%94%E7%9B%9F [全球資訊網協會]
# 外部連結: /wiki/%E5%9C%8B%E9%9A%9B%E6%A8%99%E6%BA%96%E5%8C%96%E7%B5%84%E7%B9%94 [ISO]
# 外部連結: /wiki/IEC [IEC]
# 外部連結: /wiki/%E7%B6%B2%E9%A0%81%E8%B6%85%E6%96%87%E6%9C%AC%E6%8A%80%E8%A1%93%E5%B7%A5%E4%BD%9C%E5%B0%8F%E7%B5%84 [網頁超文字應用技術工作小組]
# 外部連結: /wiki/XML [XML]
# 外部連結: /wiki/%E6%80%AA%E5%BC%82%E6%A8%A1%E5%BC%8F [標準模式]
# 外部連結: /wiki/Hello_World [Hello World]
# 外部連結: /wiki/%E6%80%AA%E5%BC%82%E6%A8%A1%E5%BC%8F [怪異模式]
# 外部連結: /wiki/%E6%8F%9B%E8%A1%8C [換行]
# 外部連結: /wiki/%E9%98%BF%E6%8B%89%E4%BC%AF%E8%AF%AD [阿拉伯語]
# 外部連結: /wiki/%E6%B3%A2%E6%96%AF%E8%AF%AD [波斯語]
# 外部連結: /wiki/%E5%B8%8C%E4%BC%AF%E6%9D%A5%E8%AF%AD [希伯來語]
# 外部連結: /wiki/%E5%AD%97%E5%85%83%E5%80%BC%E5%8F%83%E8%80%83 [字元值參考]
# 外部連結: /wiki/%E7%94%A8%E6%88%B7%E4%BB%A3%E7%90%86 [用戶代理]
# 外部連結: /wiki/%E7%BD%91%E7%BB%9C%E7%88%AC%E8%99%AB [搜尋和索引]
# 外部連結: /wiki/%E5%AD%97%E7%AC%A6%E7%BC%96%E7%A0%81 [字元編碼]
# 外部連結: /wiki/UTF-8 [UTF-8]
# 外部連結: /wiki/Unicode [Unicode]
# 外部連結: /wiki/%E6%95%B8%E6%93%9A%E9%A1%9E%E5%9E%8B [資料類型]
# 外部連結: /wiki/%E6%80%AA%E5%BC%82%E6%A8%A1%E5%BC%8F [怪異模式]
# 外部連結: /wiki/%E6%96%87%E6%A1%A3%E7%B1%BB%E5%9E%8B%E5%AE%9A%E4%B9%89 [文件類型定義]
# 外部連結: /wiki/HTML5 [HTML5]
# 外部連結: /wiki/%E6%80%AA%E5%BC%82%E6%A8%A1%E5%BC%8F [怪異模式]
# 外部連結: /wiki/Span_and_div [span與div]
# 外部連結: /wiki/%E5%B1%82%E5%8F%A0%E6%A0%B7%E5%BC%8F%E8%A1%A8 [CSS]
# 外部連結: /wiki/%E5%91%88%E7%8E%B0%E4%B8%8E%E5%86%85%E5%AE%B9%E5%88%86%E7%A6%BB [呈現與內容分離]
# 外部連結: /wiki/%E8%AF%AD%E4%B9%89%E7%BD%91 [語意網]
# 外部連結: /wiki/%E8%92%82%E5%A7%86%C2%B7%E4%BC%AF%E7%BA%B3%E6%96%AF-%E6%9D%8E [提姆·柏內茲-李]
# 外部連結: /wiki/Web_2.0 [Web 2.0]
# 外部連結: /wiki/%E6%B7%B7%E6%90%AD_(%E4%BA%92%E8%81%AF%E7%B6%B2) [混搭]
# 外部連結: /wiki/%E6%A0%BC%E5%83%B9 [價格比較網站]
# 外部連結: /wiki/%E8%81%9A%E5%90%88%E5%99%A8 [聚合]
# 外部連結: /wiki/%E7%B6%B2%E9%A0%81%E9%96%8B%E7%99%BC%E8%80%85 [網頁開發者]
# 外部連結: /wiki/API [API]
# 外部連結: /wiki/%E7%B6%B2%E8%B7%AF%E8%9C%98%E8%9B%9B [網路爬蟲]
# 外部連結: /wiki/%E7%AE%97%E6%B3%95 [演算法]
# 外部連結: /wiki/%E7%BD%91%E7%BB%9C%E6%90%9C%E7%B4%A2%E5%BC%95%E6%93%8E [搜尋工具]
# 外部連結: /wiki/%E7%B6%B2%E9%A0%81%E4%BC%BA%E6%9C%8D%E5%99%A8 [網頁伺服器]
# 外部連結: /wiki/%E8%B6%85%E6%96%87%E6%9C%AC%E4%BC%A0%E8%BE%93%E5%8D%8F%E8%AE%AE [超文字傳輸協定]
# 外部連結: /wiki/%E7%94%B5%E5%AD%90%E9%82%AE%E4%BB%B6 [電子郵件]
# 外部連結: /wiki/%E4%B8%87%E7%BB%B4%E7%BD%91 [全球資訊網]
# 外部連結: /wiki/HTTP [HTTP]
# 外部連結: /wiki/%E6%96%87%E4%BB%B6%E9%A1%9E%E5%9E%8B [檔案類型]
# 外部連結: /wiki/%E5%85%83%E6%95%B0%E6%8D%AE [元資料]
# 外部連結: /wiki/MIME [MIME]
# 外部連結: /wiki/HTML%E5%AD%97%E7%AC%A6%E7%BC%96%E7%A0%81 [HTML字元編碼]
# 外部連結: /wiki/XML [XML]
# 外部連結: /wiki/%E8%AF%AD%E6%B3%95%E9%94%99%E8%AF%AF [語法錯誤]
# 外部連結: /wiki/%E7%BA%AF%E6%96%87%E6%9C%AC [純文字]
# 外部連結: /wiki/%E8%AF%AD%E4%B9%89%E7%BD%91 [語意]
# 外部連結: /wiki/%E5%9B%BE%E5%BD%A2%E7%94%A8%E6%88%B7%E7%95%8C%E9%9D%A2 [圖形化使用者介面]
# 外部連結: /wiki/%E9%92%93%E9%B1%BC%E5%BC%8F%E6%94%BB%E5%87%BB [釣魚攻擊]
# 外部連結: /wiki/%E5%9E%83%E5%9C%BE%E9%9B%BB%E9%83%B5 [垃圾郵件]
# 外部連結: /wiki/%E6%96%87%E4%BB%B6%E6%89%A9%E5%B1%95%E5%90%8D [副檔名]
# 外部連結: /wiki/DOS [DOS]
# 外部連結: /wiki/FAT [FAT]
# 外部連結: /wiki/8.3 [3個字母]
# 外部連結: /wiki/Microsoft_Windows [Microsoft Windows]
# 外部連結: /wiki/Cookie [Cookie]
# 外部連結: /wiki/%E6%B3%A8%E5%86%8C%E8%A1%A8 [登錄檔]
# 外部連結: /wiki/EXE%E6%A0%BC%E5%BC%8F [EXE檔案]
# 外部連結: /wiki/%E6%89%80%E8%A6%8B%E5%8D%B3%E6%89%80%E5%BE%97 [所見即所得]
# 外部連結: /wiki/%E5%9B%BE%E5%BD%A2%E7%94%A8%E6%88%B7%E7%95%8C%E9%9D%A2 [圖形化使用者介面]
# 外部連結: /wiki/%E6%96%87%E5%AD%97%E5%A4%84%E7%90%86%E5%99%A8 [文書處理器]
# 外部連結: /wiki/WYSIWYM [WYSIWYM]
# 遞迴層[2] - /wiki/%E5%9C%96%E7%89%87 (圖片)
# 外部連結: /wiki/%E7%85%A7%E7%9B%B8%E6%9C%BA [照相機]
# 外部連結: /wiki/%E9%95%9C%E5%AD%90 [鏡子]
# 外部連結: /wiki/%E6%9C%9B%E8%BF%9C%E9%95%9C [望遠鏡]
# 外部連結: /wiki/%E6%98%BE%E5%BE%AE%E9%95%9C [顯微鏡]
# 外部連結: /wiki/%E6%95%B0%E5%AD%97%E5%9B%BE%E5%83%8F [數位影像]
# 外部連結: /wiki/%E5%9B%BE%E5%83%8F%E5%88%86%E6%9E%90 [圖像分析]
# 外部連結: /wiki/%E5%9B%BE%E5%83%8F%E5%A4%84%E7%90%86 [圖像處理]
# 外部連結: /wiki/%E5%9C%96%E7%89%87 [圖片]
# 外部連結: /wiki/%E7%85%A7%E7%89%87 [相片]
# 外部連結: /wiki/%E5%BD%B1%E7%89%87 [影片]
# 遞迴層[2] - /wiki/%E5%BD%B1%E7%89%87 (影片)
# 遞迴層[2] - /wiki
# 外部連結: /wiki/%E5%9B%BD%E9%99%85%E7%94%B5%E5%B7%A5%E5%A7%94%E5%91%98%E4%BC%9A [國際電工委員會]
# 外部連結: /wiki/%E8%B5%AB%E8%8C%B2 [赫茲]
# 外部連結: /wiki/%E5%B7%A5%E4%B8%9A [工業]
# 外部連結: /wiki/%E5%86%9B%E4%BA%8B [軍事]
# 外部連結: /wiki/%E5%8C%BB%E7%96%97 [醫療]
# 外部連結: /wiki/%E6%BD%9C%E8%89%87 [潛艇]
# 外部連結: /wiki/%E5%A3%B0%E5%91%90 [聲吶]
# 外部連結: /wiki/%E8%83%86%E7%BB%93%E7%9F%B3 [膽結石]
# 外部連結: /wiki/%E7%81%AB%E5%B1%B1%E7%88%86%E7%99%BC [火山爆發]
# 外部連結: /wiki/%E9%BE%99%E5%8D%B7%E9%A3%8E [龍捲風]
# 外部連結: /wiki/%E9%9B%B7%E6%9A%B4 [雷暴]
# 外部連結: /wiki/%E5%8F%B0%E9%A3%8E [颱風]
# 外部連結: /wiki/%E6%A0%B8%E8%AF%95%E9%AA%8C [核試驗]
# 外部連結: /wiki/%E7%81%AB%E7%AE%AD [火箭]
# 外部連結: /wiki/%E5%A3%B0%E5%8E%8B [聲壓]
# 外部連結: /wiki/%E9%AB%98%E8%A1%80%E5%8E%8B [高血壓]
# 外部連結: /wiki/%E7%9D%A1%E7%9C%A0 [睡眠]
# 外部連結: /wiki/%E5%9B%9E%E9%9F%B3 [回音]
# 遞迴層[2] - /wiki/%E5%A4%9A%E5%AA%92%E9%AB%94 (多媒體)
# 外部連結: /wiki/%E5%AA%92%E4%BD%93 [媒體]
# 外部連結: /wiki/%E6%96%87%E5%AD%97 [文字]
# 外部連結: /wiki/%E5%9C%96%E7%89%87 [圖片]
# 外部連結: /wiki/%E7%85%A7%E7%89%87 [照片]
# 外部連結: /wiki/%E5%A3%B0%E9%9F%B3 [聲音]
# 外部連結: /wiki/%E5%8A%A8%E7%94%BB [動畫]
# 外部連結: /wiki/%E5%BD%B1%E7%89%87 [影片]
# 外部連結: /wiki/%E7%A8%8B%E5%BA%8F [程序]
# 外部連結: /wiki/%E4%BA%92%E5%8B%95 [互動]
# 外部連結: /wiki/TCP [TCP]
# 外部連結: /wiki/UDP [UDP]
# 外部連結: /wiki/HTML [HTML]
# 外部連結: /wiki/XML [XML]
# 外部連結: /wiki/VRML [VRML]
# 外部連結: /wiki/%E5%B9%BF%E5%91%8A [廣告]
# 外部連結: /wiki/%E8%89%BA%E6%9C%AF [藝術]
# 外部連結: /wiki/%E6%95%99%E8%82%B2 [教育]
# 外部連結: /wiki/%E5%A8%B1%E4%B9%90 [娛樂]
# 外部連結: /wiki/%E4%B8%8B%E8%BD%BD [下載]
# 外部連結: /wiki/%E4%BA%92%E5%8B%95 [互動]
# 外部連結: /wiki/%E8%A7%86%E8%A7%89 [視覺]
# 外部連結: /wiki/%E5%90%AC%E8%A7%89 [聽覺]
# 外部連結: /wiki/%E8%A7%A6%E8%A7%89 [觸覺]
# 外部連結: /wiki/%E5%8F%8D%E9%A6%88 [反饋]
# 外部連結: /wiki/%E5%A4%A7%E7%9C%BE%E5%82%B3%E5%AA%92 [大眾傳媒]
# 遞迴層[2] - /wiki/%E7%B6%B2%E9%9A%9B%E7%B6%B2%E8%B7%AF (網際網路)
# 外部連結: /wiki/20%E4%B8%96%E7%B4%80 [20世紀]
# 外部連結: /wiki/%E7%94%B5%E8%84%91%E7%BD%91%E7%BB%9C [電腦網路]
# 外部連結: /wiki/%E7%B6%B2%E8%B7%AF [網路]
# 外部連結: /wiki/%E7%BD%91%E7%BB%9C%E5%8D%8F%E8%AE%AE [網路協定]
# 外部連結: /wiki/%E5%AD%B8%E8%A1%93%E7%95%8C [學術界]
# 外部連結: /wiki/%E7%94%B5%E5%AD%90%E6%8A%80%E6%9C%AF [電子]
# 外部連結: /wiki/%E7%84%A1%E7%B7%9A [無線]
# 外部連結: /wiki/%E5%85%89%E7%BA%96%E7%B6%B2%E8%B7%AF [光纖網路技術]
# 外部連結: /wiki/%E8%B6%85%E6%96%87%E6%9C%AC [超文字]
# 外部連結: /wiki/%E8%90%AC%E7%B6%AD%E7%B6%B2 [全球資訊網]
# 外部連結: /wiki/%E9%9B%BB%E5%AD%90%E9%83%B5%E4%BB%B6 [電子郵件]
# 外部連結: /wiki/%E7%B6%B2%E9%9A%9B%E5%8D%94%E8%AD%B0%E9%80%9A%E8%A9%B1%E6%8A%80%E8%A1%93 [通話]
# 外部連結: /wiki/%E6%AA%94%E6%A1%88%E5%88%86%E4%BA%AB [檔案分享]
# 外部連結: /wiki/%E7%BE%8E%E5%9C%8B%E8%81%AF%E9%82%A6%E6%94%BF%E5%BA%9C [美國聯邦政府]
# 外部連結: /wiki/ARPANET [ARPANET]
# 外部連結: /wiki/TCP/IP [TCP/IP]
# 外部連結: /wiki/%E5%88%86%E6%95%A3%E7%BD%91%E7%BB%9C [分散網路]
# 外部連結: /wiki/%E6%8E%92%E9%98%9F%E8%AE%BA [排隊論]
# 外部連結: /wiki/%E5%B0%81%E5%8C%85%E4%BA%A4%E6%8F%9B [封包交換]
# 外部連結: /wiki/%E7%BE%8E%E5%9B%BD%E5%9B%BD%E9%98%B2%E9%83%A8 [美國國防部]
# 外部連結: /wiki/%E5%9C%8B%E9%98%B2%E9%AB%98%E7%AD%89%E7%A0%94%E7%A9%B6%E8%A8%88%E5%8A%83%E7%BD%B2 [高等研究計劃署]
# 外部連結: /wiki/%E5%86%B7%E6%88%98 [冷戰]
# 外部連結: /wiki/ARPANET [ARPANET]
# 外部連結: /wiki/%E4%BC%A6%E7%BA%B3%E5%BE%B7%C2%B7%E5%85%8B%E8%8E%B1%E5%9B%A0%E7%BD%97%E5%85%8B [倫納德·克萊因羅克]
# 外部連結: /wiki/%E5%8A%A0%E5%88%A9%E7%A6%8F%E5%B0%BC%E4%BA%9E%E5%A4%A7%E5%AD%B8%E6%B4%9B%E6%9D%89%E7%A3%AF%E5%88%86%E6%A0%A1 [加利福尼亞大學洛杉磯分校]
# 外部連結: /wiki/%E9%97%A8%E6%B4%9B%E5%B8%95%E5%85%8B_(%E5%8A%A0%E5%88%A9%E7%A6%8F%E5%B0%BC%E4%BA%9A%E5%B7%9E) [加利福尼亞州門羅帕克]
# 外部連結: /wiki/%E9%81%93%E6%A0%BC%E6%8B%89%E6%96%AF%C2%B7%E6%81%A9%E6%A0%BC%E5%B0%94%E5%B7%B4%E7%89%B9 [道格拉斯·恩格爾巴特]
# 外部連結: /wiki/%E5%8A%A0%E5%88%A9%E7%A6%8F%E5%B0%BC%E4%BA%9E%E5%A4%A7%E5%AD%B8%E8%81%96%E5%A1%94%E8%8A%AD%E8%8A%AD%E6%8B%89%E5%88%86%E6%A0%A1 [加利福尼亞大學聖塔芭芭拉分校]
# 外部連結: /wiki/%E7%8A%B9%E4%BB%96%E5%A4%A7%E5%AD%A6 [猶他大學]
# 外部連結: /wiki/%E7%BD%97%E4%BC%AF%E7%89%B9%C2%B7%E5%8D%A1%E6%81%A9 [羅伯特·卡恩]
# 外部連結: /wiki/%E6%96%87%E9%A0%93%C2%B7%E7%91%9F%E5%A4%AB [文頓·瑟夫]
# 外部連結: /wiki/TCP/IP [TCP/IP]
# 外部連結: /wiki/%E5%9B%BE%E7%81%B5%E5%A5%96 [圖靈獎]
# 外部連結: /wiki/%E7%BE%8E%E5%9B%BD%E5%9B%BD%E5%AE%B6%E7%A7%91%E5%AD%A6%E5%9F%BA%E9%87%91%E4%BC%9A [美國國家科學基金會]
# 外部連結: /wiki/%E8%B6%85%E7%B4%9A%E9%9B%BB%E8%85%A6 [超級電腦]
# 外部連結: /wiki/%E4%BA%92%E8%81%AF%E7%B6%B2%E6%9C%8D%E5%8B%99%E6%8F%90%E4%BE%9B%E5%95%86 [網際網路服務提供商]
# 外部連結: /wiki/CompuServe [CompuServe]
# 外部連結: /wiki/%E5%BA%B7%E5%A5%88%E5%B0%94%E5%A4%A7%E5%AD%A6 [康奈爾大學]
# 外部連結: /wiki/%E6%AD%90%E6%B4%B2%E6%A0%B8%E5%AD%90%E7%A0%94%E7%A9%B6%E4%B8%AD%E5%BF%83 [歐洲核子研究中心]
# 外部連結: /wiki/%E8%92%82%E5%A7%86%C2%B7%E4%BC%AF%E7%BA%B3%E6%96%AF-%E6%9D%8E [提姆·柏內茲-李]
# 外部連結: /wiki/WorldWideWeb [第一個網頁瀏覽器]
# 外部連結: /wiki/%E4%B8%87%E7%BB%B4%E7%BD%91 [全球資訊網]
# 外部連結: /wiki/%E8%B6%85%E6%96%87%E6%9C%AC%E5%82%B3%E8%BC%B8%E5%8D%94%E5%AE%9A [超文字傳輸協定]
# 外部連結: /wiki/%E8%B6%85%E6%96%87%E6%9C%AC%E6%A0%87%E8%AE%B0%E8%AF%AD%E8%A8%80 [超文字標記語言]
# 外部連結: /wiki/%E7%B6%B2%E9%A0%81%E7%80%8F%E8%A6%BD%E5%99%A8 [網頁瀏覽器]
# 外部連結: /wiki/%E7%B6%B2%E9%A0%81%E4%BC%BA%E6%9C%8D%E5%99%A8 [網頁伺服器]
# 外部連結: /wiki/%E7%B6%B2%E7%AB%99 [網站]
# 外部連結: /wiki/ARPANET [ARPANET]
# 外部連結: /wiki/%E7%BE%8E%E8%81%94%E7%A4%BE [美聯社]
# 外部連結: /wiki/%E4%B8%87%E7%BB%B4%E7%BD%91 [web]
# 外部連結: /wiki/%E7%BA%BD%E7%BA%A6%E6%97%B6%E6%8A%A5 [紐約時報]
# 外部連結: /wiki/%E6%92%A5%E8%99%9F%E9%80%A3%E7%B7%9A [電話撥號]
# 外部連結: /wiki/%E7%B6%B2%E9%9A%9B%E7%B6%B2%E8%B7%AF%E5%8D%94%E5%AE%9A [網際網路協定]
# 外部連結: /wiki/IPv4 [IPv4]
# 外部連結: /wiki/IP%E5%9C%B0%E5%9D%80 [IP位址]
# 外部連結: /wiki/IPv6 [IPv6]
# 外部連結: /wiki/%E7%94%A8%E6%88%B7%E6%95%B0%E6%8D%AE%E6%8A%A5%E5%8D%8F%E8%AE%AE [UDP協定]
# 外部連結: /wiki/%E4%BC%A0%E8%BE%93%E6%8E%A7%E5%88%B6%E5%8D%8F%E8%AE%AE [TCP協定]
# 外部連結: /wiki/UDP [UDP]
# 外部連結: /wiki/%E6%96%87%E4%BB%B6%E4%BC%A0%E8%BE%93%E5%8D%8F%E8%AE%AE [FTP]
# 外部連結: /wiki/%E8%B6%85%E6%96%87%E6%9C%AC%E4%BC%A0%E8%BE%93%E5%8D%8F%E8%AE%AE [HTTP]
# 外部連結: /wiki/%E5%85%A8%E7%90%83%E8%B3%87%E8%A8%8A%E7%B6%B2 [全球資訊網]
# 外部連結: /wiki/%E7%A4%BE%E7%BE%A4%E5%AA%92%E9%AB%94 [社群媒體]
# 外部連結: /wiki/%E9%9B%BB%E5%AD%90%E9%83%B5%E4%BB%B6 [電子郵件]
# 外部連結: /wiki/%E8%A1%8C%E5%8B%95%E6%87%89%E7%94%A8%E7%A8%8B%E5%BC%8F [行動應用程式]
# 外部連結: /wiki/%E5%A4%9A%E4%BA%BA%E7%94%B5%E5%AD%90%E6%B8%B8%E6%88%8F [多人電子遊戲]
# 外部連結: /wiki/VoIP [網際網路通話]
# 外部連結: /wiki/%E6%AA%94%E6%A1%88%E5%88%86%E4%BA%AB [檔案分享]
# 外部連結: /wiki/%E4%B8%B2%E6%B5%81%E5%AA%92%E9%AB%94 [串流媒體]
# 外部連結: /wiki/%E4%BC%BA%E6%9C%8D%E5%99%A8 [伺服器]
# 外部連結: /wiki/%E8%B3%87%E6%96%99%E4%B8%AD%E5%BF%83 [資料中心]
# 外部連結: /wiki/%E5%85%A7%E5%AE%B9%E5%82%B3%E9%81%9E%E7%B6%B2%E8%B7%AF [內容傳遞網路]
# 外部連結: /wiki/%E5%85%A8%E7%90%83%E8%B3%87%E8%A8%8A%E7%B6%B2 [全球資訊網]
# 外部連結: /wiki/%E9%9B%BB%E8%85%A6%E6%AA%94%E6%A1%88 [檔案]
# 外部連結: /wiki/%E5%9C%96%E7%89%87 [圖片]
# 外部連結: /wiki/%E5%A4%9A%E5%AA%92%E9%AB%94 [多媒體]
# 外部連結: /wiki/%E8%B6%85%E9%80%A3%E7%B5%90 [超連結]
# 外部連結: /wiki/%E7%B5%B1%E4%B8%80%E8%B3%87%E6%BA%90%E6%A8%99%E8%AA%8C%E7%AC%A6 [統一資源標誌符]
# 外部連結: /wiki/%E7%B6%B2%E9%A0%81%E4%BC%BA%E6%9C%8D%E5%99%A8 [網頁伺服器]
# 外部連結: /wiki/%E8%B6%85%E6%96%87%E6%9C%AC%E5%82%B3%E8%BC%B8%E5%8D%94%E8%AD%B0 [超文字傳輸協定]
# 外部連結: /wiki/%E5%BE%AE%E8%BB%9F [微軟]
# 外部連結: /wiki/Internet_Explorer [Internet Explorer]
# 外部連結: /wiki/Microsoft_Edge [Edge]
# 外部連結: /wiki/Mozilla_Firefox [Mozilla Firefox]
# 外部連結: /wiki/Opera%E9%9B%BB%E8%85%A6%E7%80%8F%E8%A6%BD%E5%99%A8 [Opera]
# 外部連結: /wiki/%E8%98%8B%E6%9E%9C%E5%85%AC%E5%8F%B8 [蘋果公司]
# 外部連結: /wiki/Safari [Safari]
# 外部連結: /wiki/Google_Chrome [Google Chrome]
# 外部連結: /wiki/%E5%A4%9A%E5%AA%92%E9%AB%94 [多媒體]
# 外部連結: /wiki/%E7%BD%91%E9%A1%B5%E6%B8%B8%E6%88%8F [遊戲]
# 外部連結: /wiki/Yahoo [Yahoo]
# 外部連結: /wiki/Bing [Bing]
# 外部連結: /wiki/Google [Google]
# 外部連結: /wiki/%E6%90%9C%E5%B0%8B%E5%BC%95%E6%93%8E [搜尋引擎]
# 外部連結: /wiki/%E9%97%9C%E9%8D%B5%E5%AD%97 [關鍵字]
# 外部連結: /wiki/%E9%9B%BB%E5%AD%90%E9%83%B5%E4%BB%B6 [電子郵件]
# 外部連結: /wiki/%E9%9B%BB%E5%AD%90%E9%83%B5%E4%BB%B6%E5%9C%B0%E5%9D%80 [電子郵件位址]
# 外部連結: /wiki/%E6%AA%94%E6%A1%88%E5%88%86%E4%BA%AB [檔案分享]
# 外部連結: /wiki/%E6%AA%94%E6%A1%88%E5%82%B3%E8%BC%B8%E5%8D%94%E5%AE%9A [檔案傳輸協定]
# 外部連結: /wiki/%E6%AA%94%E6%A1%88%E4%BC%BA%E6%9C%8D%E5%99%A8 [檔案伺服器]
# 外部連結: /wiki/%E6%83%A1%E6%84%8F%E8%BB%9F%E9%AB%94 [惡意軟體]
# 外部連結: /wiki/%E9%9B%BB%E8%85%A6%E7%97%85%E6%AF%92 [電腦病毒]
# 外部連結: /wiki/%E9%9B%BB%E8%85%A6%E8%A0%95%E8%9F%B2 [電腦蠕蟲]
# 外部連結: /wiki/%E9%98%BB%E6%96%B7%E6%9C%8D%E5%8B%99%E6%94%BB%E6%93%8A [阻斷服務攻擊]
# 外部連結: /wiki/%E5%8B%92%E7%B4%A2%E8%BB%9F%E9%AB%94 [勒索軟體]
# 外部連結: /wiki/%E6%AE%AD%E5%B1%8D%E7%B6%B2%E7%B5%A1 [殭屍網路]
# 外部連結: /wiki/%E9%96%93%E8%AB%9C%E8%BB%9F%E4%BB%B6 [間諜軟體]
# 外部連結: /wiki/%E7%94%B5%E8%84%91%E7%8A%AF%E7%BD%AA [網路犯罪]
# 外部連結: /wiki/%E7%BE%8E%E5%9C%8B%E5%9C%8B%E5%AE%B6%E5%AE%89%E5%85%A8%E5%B1%80 [美國國家安全域]
# 外部連結: /wiki/%E4%B8%AD%E6%83%85%E5%B1%80 [中情局]
# 外部連結: /wiki/%E7%88%B1%E5%BE%B7%E5%8D%8E%C2%B7%E6%96%AF%E8%AF%BA%E7%99%BB [史諾登]
# 外部連結: /wiki/%E8%A1%9B%E5%A0%B1 [衛報]
# 外部連結: /wiki/%E8%8F%AF%E7%9B%9B%E9%A0%93%E9%83%B5%E5%A0%B1 [華盛頓郵報]
# 外部連結: /wiki/%E4%B8%AD%E5%8D%8E%E4%BA%BA%E6%B0%91%E5%85%B1%E5%92%8C%E5%9B%BD [中華人民共和國]
# 外部連結: /wiki/%E6%B2%99%E7%89%B9%E9%98%BF%E6%8B%89%E4%BC%AF [沙烏地阿拉伯]
# 外部連結: /wiki/%E6%94%BF%E6%B2%BB [政治]
# 外部連結: /wiki/%E5%AE%97%E6%95%99 [宗教]
# 外部連結: /wiki/%E4%BF%A1%E6%81%AF%E6%8A%80%E6%9C%AF [資訊科技]
# 外部連結: /wiki/%E6%9C%9D%E9%B2%9C [朝鮮]
# 外部連結: /wiki/%E5%9C%8B%E5%AE%B6%E5%8D%80%E5%9F%9F%E7%B6%B2%E8%B7%AF [國家區域網路]
# 外部連結: /wiki/%E7%B6%93%E6%BF%9F%E5%90%88%E4%BD%9C%E7%99%BC%E5%B1%95%E7%B5%84%E7%B9%94 [經濟合作發展組織]
# 外部連結: /wiki/%E5%86%B0%E5%B3%B6 [冰島]
# 外部連結: /wiki/%E9%9F%A9%E5%9B%BD [韓國]
# 外部連結: /wiki/%E8%8D%B7%E8%98%AD [荷蘭]
# 外部連結: /wiki/%E4%B8%B9%E9%BA%A5 [丹麥]
# 外部連結: /wiki/%E7%91%9E%E5%A3%AB [瑞士]
# 外部連結: /wiki/%E7%BE%8E%E5%9C%8B [美國]
# 外部連結: /wiki/%E4%B8%AD%E5%9B%BD%E4%BA%92%E8%81%94%E7%BD%91%E7%BB%9C%E4%BF%A1%E6%81%AF%E4%B8%AD%E5%BF%83 [中國互聯網絡信息中心]
# 外部連結: /wiki/%E7%BD%91%E6%B0%91 [網友]
# 遞迴層[2] - /wiki/ENQUIRE (ENQUIRE)
# 外部連結: /wiki/%E6%AD%90%E6%B4%B2%E6%A0%B8%E5%AD%90%E7%A0%94%E7%A9%B6%E4%B8%AD%E5%BF%83 [歐洲核子研究中心]
# 外部連結: /wiki/%E6%8F%90%E5%A7%86%C2%B7%E6%9F%8F%E5%85%A7%E8%8C%B2-%E6%9D%8E [提姆·柏內茲-李]
# 外部連結: /wiki/%E8%BB%9F%E9%AB%94 [軟體]
# 外部連結: /wiki/%E5%85%A8%E7%90%83%E8%B3%87%E8%A8%8A%E7%B6%B2 [全球資訊網]
# 外部連結: /wiki/%E8%B6%85%E6%96%87%E5%AD%97 [超文字]
# 外部連結: /wiki/%E8%AA%9E%E7%BE%A9%E7%B6%B2 [語義網]
# 外部連結: /wiki/%E7%A1%AC%E9%AB%94 [硬體]
# 外部連結: /wiki/%E8%BB%9F%E9%AB%94 [軟體]
# 外部連結: /wiki/%E9%9B%BB%E5%AD%90%E9%83%B5%E4%BB%B6 [電子郵件]
# 外部連結: /wiki/OpenVMS [VAX / VMS Notes]
# 外部連結: /wiki/Usenet [Usenet]
# 遞迴層[2] - /wiki/%E6%95%B0%E6%8D%AE%E5%BA%93 (資料庫)
# 外部連結: /wiki/%E6%A1%A3%E6%A1%88%E6%9F%9C [檔案櫃]
# 外部連結: /wiki/%E6%AA%94%E6%A1%88 [檔案]
# 外部連結: /wiki/%E6%AA%94%E6%A1%88 [檔案]
# 外部連結: /wiki/%E5%85%B1%E4%BA%AB [共享]
# 外部連結: /wiki/%E6%95%B0%E6%8D%AE%E5%86%97%E4%BD%99 [冗餘度]
# 外部連結: /wiki/%E9%9B%86%E5%90%88 [集合]
# 外部連結: /wiki/Tablespace [Tablespace]
# 外部連結: /wiki/%E6%93%8D%E4%BD%9C%E7%B3%BB%E7%BB%9F [作業系統]
# 外部連結: /wiki/%E8%AE%A1%E7%AE%97%E6%9C%BA [電腦]
# 外部連結: /wiki/%E6%95%B0%E6%8D%AE [資料]
# 外部連結: /wiki/%E7%A8%8B%E5%BA%8F [程式]
# 外部連結: /wiki/%E5%8F%AF%E6%89%A9%E5%B1%95%E6%80%A7 [可延伸性]
# 外部連結: /wiki/%E7%B3%BB%E7%BB%9F%E8%BD%AF%E4%BB%B6 [系統軟體]
# 外部連結: /wiki/%E6%95%B0%E6%8D%AE%E5%BA%93%E7%AE%A1%E7%90%86%E7%B3%BB%E7%BB%9F [資料庫管理系統]
# 外部連結: /wiki/DBMS [DBMS]
# 外部連結: /wiki/%E8%B3%87%E6%96%99%E5%BA%AB [資料庫]
# 外部連結: /wiki/%E8%BB%9F%E9%AB%94 [軟體]
# 外部連結: /wiki/%E9%97%9C%E8%81%AF%E6%A8%A1%E5%9E%8B [關聯式]
# 外部連結: /wiki/XML [XML]
# 外部連結: /wiki/SQL [SQL]
# 外部連結: /wiki/%E5%88%86%E5%B8%83%E5%BC%8F%E6%95%B0%E6%8D%AE%E5%BA%93 [分散式資料庫]
# 外部連結: /wiki/%E9%96%8B%E6%94%BE%E5%BC%8F%E8%B3%87%E6%96%99%E5%BA%AB%E9%80%A3%E6%8E%A5 [開放式資料庫連接]
# 外部連結: /wiki/%E4%BA%92%E8%81%94%E7%BD%91 [網際網路]
# 外部連結: /wiki/XML [XML]
# 外部連結: /wiki/Java [Java]
# 外部連結: /wiki/%E5%BA%94%E7%94%A8%E6%9C%8D%E5%8A%A1%E5%99%A8 [應用伺服器]
# 外部連結: /wiki/Oracle [Oracle公司]
# 外部連結: /wiki/%E5%AE%89%E5%85%A8%E6%A8%99%E6%BA%96 [安全標準]
# 外部連結: /wiki/%E7%94%B5%E5%AD%90%E5%95%86%E5%8A%A1 [電子商務]
# 外部連結: /wiki/%E6%95%B0%E5%AD%97%E5%9B%BE%E4%B9%A6%E9%A6%86 [數字圖書館]
# 外部連結: /wiki/%E6%95%B0%E6%8D%AE%E4%BA%A4%E6%8D%A2 [資料交換]
# 外部連結: /wiki/%E7%A7%BB%E5%8A%A8%E9%80%9A%E4%BF%A1%E6%8A%80%E6%9C%AF [行動通訊技術]
# 外部連結: /wiki/%E7%A9%BA%E5%80%BC [空值]
# 外部連結: /wiki/ACID [ACID]
# 遞迴層[2] - /wiki/%E8%AF%AD%E4%B9%89%E7%BD%91 (語意網)
# 外部連結: /wiki/%E8%8B%B1%E8%AF%AD [英語]
# 外部連結: /wiki/%E4%B8%87%E7%BB%B4%E7%BD%91%E8%81%94%E7%9B%9F [全球資訊網協會]
# 外部連結: /wiki/%E8%92%82%E5%A7%86%C2%B7%E4%BC%AF%E7%BA%B3%E6%96%AF-%E6%9D%8E [提姆·柏內茲-李]
# 外部連結: /wiki/%E4%B8%87%E7%BB%B4%E7%BD%91 [全球資訊網]
# 外部連結: /wiki/HTML [HTML]
# 外部連結: /wiki/%E8%AE%A1%E7%AE%97%E6%9C%BA [電腦]
# 外部連結: /wiki/%E5%85%83%E6%95%B0%E6%8D%AE [元資料]
# 外部連結: /wiki/%E7%BD%AE%E6%A0%87%E8%AF%AD%E8%A8%80 [標示語言]
# 外部連結: /wiki/XML [text-and-markup]
# 外部連結: /wiki/%E7%9F%A5%E8%AF%86%E8%A1%A8%E7%8E%B0 [知識表現]
# 外部連結: /wiki/%E8%AF%AD%E4%B9%89%E7%BD%91%E7%BB%9C_(%E8%AE%A1%E7%AE%97%E6%9C%BA%E7%A7%91%E5%AD%A6) [語意網絡]
# 外部連結: /wiki/%E5%85%A8%E7%90%83%E8%B3%87%E8%A8%8A%E7%B6%B2 [全球資訊網]
# 外部連結: /wiki/%E8%90%AC%E7%B6%AD%E7%B6%B2 [全球資訊網]
# 外部連結: /wiki/%E8%92%82%E5%A7%86%C2%B7%E4%BC%AF%E7%BA%B3%E6%96%AF-%E6%9D%8E [提姆·柏內茲-李]
# 外部連結: /wiki/%E5%8F%AF%E7%B8%AE%E6%94%BE%E5%90%91%E9%87%8F%E5%9C%96%E5%BD%A2 [SVG]
# 外部連結: /wiki/Web_2.0 [Web 2.0]
# 遞迴層[2] - /wiki/%E7%BD%97%E4%BC%AF%E7%89%B9%C2%B7%E5%8D%A1%E9%87%8C%E5%A5%A5 (羅伯特·卡里奧)
# 外部連結: /wiki/Help:%E6%B3%95%E8%AA%9E%E5%9C%8B%E9%9A%9B%E9%9F%B3%E6%A8%99 [[kɛˈjo]]
# 外部連結: /wiki/%E6%AF%94%E5%88%A9%E6%97%B6 [比利時]
# 外部連結: /wiki/%E4%BF%A1%E6%81%AF%E5%AD%A6 [資訊工程師]
# 外部連結: /wiki/%E8%AE%A1%E7%AE%97%E6%9C%BA%E7%A7%91%E5%AD%A6%E5%AE%B6 [電腦科學家]
# 外部連結: /wiki/CERN [CERN]
# 外部連結: /wiki/%E8%92%82%E5%A7%86%C2%B7%E4%BC%AF%E7%BA%B3%E6%96%AF-%E6%9D%8E [提姆·柏內茲-李]
# 外部連結: /wiki/%E4%B8%87%E7%BB%B4%E7%BD%91 [全球資訊網]
# 外部連結: /wiki/%E5%AE%89%E7%89%B9%E5%8D%AB%E6%99%AE [安特衛普]
# 外部連結: /wiki/%E8%8D%B7%E8%98%AD%E8%AA%9E [荷蘭語]
# 外部連結: /wiki/%E6%A0%B9%E7%89%B9%E5%A4%A7%E5%AD%A6 [根特大學]
# 外部連結: /wiki/%E5%AF%86%E6%AD%87%E6%A0%B9%E5%A4%A7%E5%AD%A6 [密西根大學]
# 外部連結: /wiki/Fortran [Fortran]
# 外部連結: /wiki/%E6%AD%90%E6%B4%B2%E6%A0%B8%E5%AD%90%E7%A0%94%E7%A9%B6%E7%B5%84%E7%B9%94 [歐洲核子研究組織]
# 外部連結: /wiki/%E8%92%82%E5%A7%86%C2%B7%E4%BC%AF%E7%BA%B3%E6%96%AF-%E6%9D%8E [提姆·柏內茲-李]
# 外部連結: /wiki/%E8%B6%85%E6%96%87%E6%9C%AC [超文字]
# 外部連結: /wiki/%E4%B8%87%E7%BB%B4%E7%BD%91 [全球資訊網]
# 外部連結: /wiki/%E5%BC%97%E5%8A%B3%E6%81%A9%E9%9C%8D%E5%A4%AB%E5%8D%8F%E4%BC%9A [弗勞恩霍夫協會]
# 外部連結: /wiki/%E6%AC%A7%E7%9B%9F%E5%A7%94%E5%91%98%E4%BC%9A [歐盟執委會]
# 外部連結: /wiki/%E5%85%AC%E6%9C%89%E9%A2%86%E5%9F%9F [公有領域]
# 外部連結: /wiki/%E6%AC%A7%E7%9B%9F%E5%A7%94%E5%91%98%E4%BC%9A [歐盟執委會]
# 外部連結: /wiki/W3C [W3C]
# 外部連結: /wiki/%E6%97%A0%E7%A5%9E%E8%AE%BA [無神論]
# 遞迴層[2] - /wiki/NeXT (NeXT)
# 外部連結: /wiki/%E8%8B%B1%E8%AA%9E [英語]
# 外部連結: /wiki/%E7%BE%8E%E5%9C%8B [美國]
# 外部連結: /wiki/%E5%8A%A0%E5%88%A9%E7%A6%8F%E5%B0%BC%E4%BA%9A%E5%B7%9E [加利福尼亞州]
# 外部連結: /wiki/%E7%B4%85%E6%9C%A8%E5%9F%8E [紅木城]
# 外部連結: /wiki/%E5%B7%A5%E4%BD%9C%E7%AB%99 [工作站]
# 外部連結: /wiki/%E8%98%8B%E6%9E%9C%E5%85%AC%E5%8F%B8 [蘋果公司]
# 外部連結: /wiki/%E8%98%8B%E6%9E%9C%E9%9B%BB%E8%85%A6 [蘋果電腦]
# 外部連結: /wiki/%E5%8F%B2%E8%92%82%E5%A4%AB%C2%B7%E8%B3%88%E4%BC%AF%E6%96%AF [史蒂夫·賈伯斯]
# 外部連結: /wiki/NeXT_Computer [NeXT Computer]
# 外部連結: /wiki/%E7%89%A9%E4%BB%B6%E5%B0%8E%E5%90%91 [物件導向]
# 外部連結: /wiki/%E4%BD%9C%E6%A5%AD%E7%B3%BB%E7%B5%B1 [作業系統]
# 外部連結: /wiki/NEXTSTEP [NEXTSTEP]
# 外部連結: /wiki/API [API]
# 外部連結: /wiki/OPENSTEP [OPENSTEP]
# 外部連結: /wiki/OPENSTEP [OPENSTEP]
# 外部連結: /wiki/%E5%8B%95%E6%85%8B%E7%B6%B2%E9%A0%81 [動態網頁]
# 外部連結: /wiki/%E7%BD%91%E7%AB%99 [網站]
# 外部連結: /wiki/%E7%BA%A6%E7%BF%B0%C2%B7%E6%96%AF%E5%8D%A1%E5%88%A9 [史考利]
# 外部連結: /wiki/%E5%B7%A5%E4%BD%9C%E7%AB%99 [工作站]
# 外部連結: /wiki/%E4%BF%9D%E7%BD%97%C2%B7%E5%85%B0%E5%BE%B7 [保羅·蘭德]
# 外部連結: /wiki/%E5%B7%A5%E4%BD%9C%E7%AB%99 [工作站]
# 外部連結: /wiki/%E8%AE%A9-%E8%B7%AF%E6%98%93%C2%B7%E5%8A%A0%E8%A5%BF [讓-路易·加西]
# 外部連結: /wiki/Unix [Unix]
# 外部連結: /wiki/%E4%BD%9C%E6%A5%AD%E7%B3%BB%E7%B5%B1 [作業系統]
# 外部連結: /wiki/%E9%A3%8E%E6%8A%95 [風投]
# 外部連結: /wiki/%E7%BD%97%E6%96%AF%C2%B7%E4%BD%A9%E7%BD%97 [羅斯·佩羅]
# 外部連結: /wiki/%E5%8F%B2%E8%92%82%E5%A4%AB%C2%B7%E8%B3%88%E4%BC%AF%E6%96%AF [史蒂夫·賈伯斯]
# 外部連結: /wiki/%E5%8A%A0%E5%B7%9E [加州]
# 外部連結: /wiki/%E6%97%A5%E6%9C%AC [日本]
# 外部連結: /wiki/%E4%BD%B3%E8%83%BD [佳能]
# 外部連結: /wiki/%E7%A3%81%E7%A2%9F%E6%A9%9F [磁碟機]
# 外部連結: /wiki/%E7%A3%81%E7%A2%9F%E6%A9%9F [磁碟機]
# 外部連結: /wiki/%E5%85%89%E7%A2%9F%E6%A9%9F [光碟機]
# 外部連結: /wiki/Sun [Sun]
# 外部連結: /wiki/OPENSTEP [OPENSTEP]
# 外部連結: /wiki/Copland_%E6%93%8D%E4%BD%9C%E7%B3%BB%E7%BB%9F [Copland]
# 外部連結: /wiki/BeOS [BeOS]
# 外部連結: /wiki/Mac_OS_X [Mac OS X]
# 外部連結: /wiki/Mac_OS_X_Server [Mac OS X Server]
# 外部連結: /wiki/Xcode [Xcode]
# 遞迴層[2] - /wiki/%E8%81%96%E8%AA%95%E7%AF%80 (聖誕節)
# ...
# 外部連結: /wiki/%E7%BE%8E%E5%9B%BD%E5%9B%BD%E5%AE%B6%E8%88%AA%E7%A9%BA%E8%88%AA%E5%A4%A9%E5%B1%80 [美國國家航空暨太空總署]
# 外部連結: /wiki/Sun_Microsystems [Sun Microsystems]
# 外部連結: /wiki/AOL [AOL]
# 外部連結: /wiki/%E6%97%B6%E4%BB%A3%E5%8D%8E%E7%BA%B3 [時代華納]
# 外部連結: /wiki/%E5%BE%AE%E8%BD%AF [微軟]
# 外部連結: /wiki/%E8%AF%BA%E5%9F%BA%E4%BA%9A [諾基亞]
# 外部連結: /wiki/%E7%88%B1%E7%AB%8B%E4%BF%A1 [愛立信]
# 外部連結: /wiki/%E9%A1%B6%E7%BA%A7%E5%9F%9F%E5%90%8D [頂級域名]
# 外部連結: /wiki/.mobi [.mobi]
# 外部連結: /wiki/%E6%96%B0%E9%97%BB%E9%9B%86%E5%9B%A2 [新聞集團]
# 外部連結: /wiki/%E7%A4%BE%E4%BA%A4%E7%BD%91%E7%BB%9C%E6%9C%8D%E5%8A%A1 [社群網站]
# 外部連結: /wiki/MySpace [MySpace]
# 外部連結: /wiki/%E9%96%8B%E6%94%BE%E6%89%8B%E6%A9%9F%E8%81%AF%E7%9B%9F [開放手機聯盟]
# 外部連結: /wiki/Android [Android]
# 外部連結: /wiki/%E8%8B%B9%E6%9E%9C [蘋果]
# 外部連結: /wiki/IOS [iOS]
# 外部連結: /wiki/%E5%BE%AE%E8%BD%AF [微軟]
# 外部連結: /wiki/Windows_Phone [Windows Phone]
# 外部連結: /wiki/%E6%8E%A7%E8%82%A1%E5%85%AC%E5%8F%B8 [控股公司]
# 外部連結: /wiki/%E6%A1%91%E5%BE%B7%E5%B0%94%C2%B7%E7%9A%AE%E8%94%A1 [桑德爾·皮查伊]
# 外部連結: /wiki/%E5%B9%BF%E5%91%8A [廣告]
# 外部連結: /wiki/DoubleClick [DoubleClick]
# 外部連結: /wiki/Google_Analytics [Google Analytics]
# 外部連結: /wiki/%E8%B6%85%E9%80%A3%E7%B5%90 [連結]
# 外部連結: /wiki/AdWords [AdWords]
# 外部連結: /wiki/AdSense [AdSense]
# 外部連結: /wiki/%E9%BB%9E%E6%93%8A%E6%AC%BA%E8%A9%90 [點擊欺詐]
# 外部連結: /wiki/%E6%95%B0%E5%AD%97%E5%8D%83%E5%B9%B4%E7%89%88%E6%9D%83%E6%B3%95 [數字千年著作權法]
# 外部連結: /wiki/%E7%BE%8E%E5%9B%BD%E5%8F%B8%E6%B3%95%E9%83%A8 [美國司法部]
# 外部連結: /wiki/%E5%8F%8D%E6%89%98%E6%8B%89%E6%96%AF%E6%B3%95 [反托拉斯]
# 外部連結: /wiki/%E9%9B%85%E8%99%8E [雅虎]
# 外部連結: /wiki/%E4%BA%92%E8%81%94%E7%BD%91 [網際網路]
# 外部連結: /wiki/%E5%90%8C%E4%B9%89%E8%AF%8D [同義詞]
# 外部連結: /wiki/%E5%A4%A9%E6%B0%94%E9%A2%84%E6%8A%A5 [天氣預報]
# 外部連結: /wiki/%E6%97%B6%E5%8C%BA [時區]
# 外部連結: /wiki/%E8%82%A1%E5%83%B9 [股價]
# 外部連結: /wiki/%E5%9C%B0%E5%9B%BE [地圖]
# 外部連結: /wiki/%E5%9C%B0%E9%9C%87 [地震]
# 外部連結: /wiki/%E6%9C%BA%E5%9C%BA [機場]
# 外部連結: /wiki/%E7%BF%BB%E8%AF%91 [翻譯]
# 外部連結: /wiki/%E7%BA%BD%E7%BA%A6%E6%97%B6%E6%8A%A5 [紐約時報]
# 外部連結: /wiki/%E7%BC%93%E5%AD%98 [快取]
# 外部連結: /wiki/%E5%86%85%E5%8D%8E%E8%BE%BE [內華達]
# 外部連結: /wiki/%E5%9C%B0%E6%96%B9%E6%B3%95%E9%99%A2 [地方法院]
# 外部連結: /wiki/%E8%BE%A9%E6%8A%A4 [辯護]
# 外部連結: /wiki/Gmail [Gmail]
# 外部連結: /wiki/%E7%94%B5%E5%AD%90%E9%82%AE%E7%AE%B1 [電子信箱]
# 外部連結: /wiki/%E8%BD%AF%E4%BB%B6%E7%89%88%E6%9C%AC%E5%91%A8%E6%9C%9F [Beta階段]
# 外部連結: /wiki/%E5%90%89%E5%AD%97%E8%8A%82 [GB]
# 外部連結: /wiki/%E5%A4%AA%E5%AD%97%E8%8A%82 [TB]
# 外部連結: /wiki/AJAX [AJAX]
# 外部連結: /wiki/Google%E6%96%87%E4%BB%B6 [Google文件]
# 外部連結: /wiki/%E5%BE%AE%E8%BD%AF [微軟]
# 外部連結: /wiki/Microsoft_Word [Microsoft Word]
# 外部連結: /wiki/Google%E6%97%A5%E5%8E%86 [Google日曆]
# 外部連結: /wiki/Google_Apps [Google Apps]
# 外部連結: /wiki/Google_Search_Appliance [Google Search Appliance]
# 外部連結: /wiki/Google%E5%8D%8F%E4%BD%9C%E5%B9%B3%E5%8F%B0 [Google協同運作平台]
# 外部連結: /wiki/Google_Apps [Google Apps]
# 外部連結: /wiki/API [API]
# 外部連結: /wiki/%E5%8A%A0%E6%8B%BF%E5%A4%A7 [加拿大]
# 外部連結: /wiki/%E5%AE%89%E5%A4%A7%E7%95%A5%E7%9C%81 [安大略省]
# 外部連結: /wiki/%E6%A1%91%E5%BE%B7%E8%B4%9D [桑德貝]
# 外部連結: /wiki/%E6%B9%96%E9%A6%96%E5%A4%A7%E5%AD%A6 [湖首大學]
# 外部連結: /wiki/Postini [Postini]
# 外部連結: /wiki/SNS [SNS]
# 外部連結: /wiki/Google_Wave [Google Wave]
# 外部連結: /wiki/Google_Buzz [Google Buzz]
# 外部連結: /wiki/Orkut [Orkut]
# 外部連結: /wiki/%E5%8D%B0%E5%BA%A6 [印度]
# 外部連結: /wiki/%E5%B7%B4%E8%A5%BF [巴西]
# 外部連結: /wiki/Google%2B [Google+]
# 外部連結: /wiki/Twitter [Twitter]
# 外部連結: /wiki/Facebook [Facebook]
# 外部連結: /wiki/%E5%8D%9A%E5%AE%A2 [部落格]
# 外部連結: /wiki/Blogger [Blogger]
# 外部連結: /wiki/PayPal [PayPal]
# 外部連結: /wiki/%E8%A6%96%E9%A0%BB%E5%88%86%E4%BA%AB%E7%B6%B2%E7%AB%99 [影片分享網站]
# 外部連結: /wiki/YouTube [YouTube]
# 外部連結: /wiki/%E5%9C%A3%E5%B8%83%E9%B2%81 [聖布魯]
# 外部連結: /wiki/Flash_Video [Flash Video]
# 外部連結: /wiki/HTML5 [HTML5]
# 外部連結: /wiki/%E5%93%A5%E4%BC%A6%E6%AF%94%E4%BA%9A%E5%B9%BF%E6%92%AD%E5%85%AC%E5%8F%B8 [哥倫比亞廣播公司]
# 外部連結: /wiki/%E8%8B%B1%E5%9B%BD%E5%B9%BF%E6%92%AD%E5%85%AC%E5%8F%B8 [英國廣播公司]
# 外部連結: /wiki/VEVO [VEVO]
# 外部連結: /wiki/Hulu [Hulu]
# 外部連結: /wiki/Google_Chrome [Google Chrome]
# 外部連結: /wiki/WebKit [WebKit]
# 外部連結: /wiki/%E6%8E%92%E7%89%88%E5%BC%95%E6%93%8E [排版引擎]
# 外部連結: /wiki/Blink [Blink]
# 外部連結: /wiki/%E6%BA%90%E4%BB%A3%E7%A0%81 [原始碼]
# 外部連結: /wiki/V8_(JavaScript%E5%BC%95%E6%93%8E) [V8 JavaScript引擎]
# 外部連結: /wiki/Chromium_(%E6%B5%8F%E8%A7%88%E5%99%A8) [Chromium]
# 外部連結: /wiki/Mac_OS_X [Mac OS X]
# 外部連結: /wiki/Linux [Linux]
# 外部連結: /wiki/BSD%E8%AE%B8%E5%8F%AF%E8%AF%81 [BSD許可證]
# 外部連結: /wiki/Microsoft_Windows [Windows]
# 外部連結: /wiki/Google_Chrome [Google Chrome]
# 外部連結: /wiki/StatCounter [StatCounter]
# 外部連結: /wiki/%E7%B6%B2%E9%A0%81%E7%80%8F%E8%A6%BD%E5%99%A8%E7%9A%84%E4%BD%BF%E7%94%A8%E5%88%86%E4%BD%88 [瀏覽器市場份額]
# 外部連結: /wiki/Internet_Explorer [IE]
# 外部連結: /wiki/Mozilla_Firefox [火狐]
# 外部連結: /wiki/Firefox [Firefox]
# 外部連結: /wiki/Firefox [Firefox]
# 外部連結: /wiki/%E8%8B%B9%E6%9E%9C%E5%85%AC%E5%8F%B8 [蘋果]
# 外部連結: /wiki/IPhone [iPhone]
# 外部連結: /wiki/Android [Android]
# 外部連結: /wiki/%E6%93%8D%E4%BD%9C%E7%B3%BB%E7%BB%9F [作業系統]
# 外部連結: /wiki/Apache%E8%AE%B8%E5%8F%AF%E8%AF%81 [Apache許可證]
# 外部連結: /wiki/%E5%BC%80%E6%BA%90 [開源]
# 外部連結: /wiki/%E8%BD%AF%E4%BB%B6%E5%BC%80%E5%8F%91%E5%B7%A5%E5%85%B7%E5%8C%85 [軟體開發套件]
# 外部連結: /wiki/%E9%96%8B%E6%94%BE%E6%89%8B%E6%A9%9F%E8%81%AF%E7%9B%9F [開放手機聯盟]
# 外部連結: /wiki/T-Mobile [T-Mobile]
# 外部連結: /wiki/Nexus_One [Nexus One]
# 外部連結: /wiki/%E6%99%BA%E8%83%BD%E6%89%8B%E6%9C%BA [智慧型手機]
# 外部連結: /wiki/%E5%BA%94%E7%94%A8%E8%BD%AF%E4%BB%B6 [應用軟體]
# 外部連結: /wiki/Google_Play [Google Play]
# 外部連結: /wiki/Java [Java]
# 外部連結: /wiki/Linux [Linux]
# 外部連結: /wiki/Google_Chrome_OS [Google Chrome OS]
# 外部連結: /wiki/%E4%B8%8A%E7%BD%91%E6%9C%AC [小筆電]
# 外部連結: /wiki/Chromium_OS [Chromium OS]
# 外部連結: /wiki/BSD%E8%AE%B8%E5%8F%AF%E8%AF%81 [BSD許可證]
# 外部連結: /wiki/Google_Chrome [Chrome瀏覽器]
# 外部連結: /wiki/%E7%94%A8%E6%88%B7%E7%95%8C%E9%9D%A2 [使用者介面]
# 外部連結: /wiki/%E7%94%B5%E8%84%91 [電腦]
# 外部連結: /wiki/%E4%BA%92%E8%81%94%E7%BD%91 [網際網路]
# 外部連結: /wiki/Google_I/O [Google I/O大會]
# 外部連結: /wiki/Chromebook [Chromebook]
# 外部連結: /wiki/%E5%AE%8F%E7%A2%81 [宏碁]
# 外部連結: /wiki/%E4%B8%89%E6%98%9F%E9%9B%BB%E5%AD%90 [三星]
# 外部連結: /wiki/Nexus_7 [Nexus 7]
# 外部連結: /wiki/Chromecast [Chromecast]
# 外部連結: /wiki/Google_Checkout [Google Checkout]
# 外部連結: /wiki/%E5%9C%98%E8%B3%BC [團購]
# 外部連結: /wiki/Groupon [Groupon]
# 外部連結: /wiki/%E4%BF%84%E5%8B%92%E5%86%88%E5%B7%9E [俄勒岡州]
# 外部連結: /wiki/%E6%B3%A2%E7%89%B9%E5%85%B0_(%E4%BF%84%E5%8B%92%E5%86%88%E5%B7%9E) [波特蘭]
# 外部連結: /wiki/%E7%BA%BD%E7%BA%A6 [紐約]
# 外部連結: /wiki/%E6%97%A7%E9%87%91%E5%B1%B1 [舊金山]
# 外部連結: /wiki/%E8%B0%B7%E6%AD%8C%E6%97%B6%E6%83%A0 [谷歌時惠]
# 外部連結: /wiki/Google_Wallet [Google Wallet]
# 外部連結: /wiki/%E8%BF%91%E5%A0%B4%E9%80%9A%E8%A8%8A [近場通訊]
# 外部連結: /wiki/Google%E7%BF%BB%E8%AF%91 [Google翻譯]
# 外部連結: /wiki/%E6%9C%BA%E5%99%A8%E7%BF%BB%E8%AF%91 [機器翻譯]
# 外部連結: /wiki/%E6%B5%8F%E8%A7%88%E5%99%A8 [瀏覽器]
# 外部連結: /wiki/%E8%AF%AD%E6%96%99%E5%BA%93%E8%AF%AD%E8%A8%80%E5%AD%A6 [語料庫語言學]
# 外部連結: /wiki/%E8%81%94%E5%90%88%E5%9B%BD [聯合國]
# 外部連結: /wiki/%E6%AC%A7%E6%B4%B2%E8%AE%AE%E4%BC%9A [歐洲議會]
# 外部連結: /wiki/Google%E6%96%B0%E9%97%BB [Google新聞]
# 外部連結: /wiki/265%E5%AF%BC%E8%88%AA [265導航]
# 外部連結: /wiki/Google%E4%BA%91%E5%B9%B3%E5%8F%B0 [Google雲平台]
# 外部連結: /wiki/Google%E5%85%89%E7%BA%A4 [Google光纖]
# 外部連結: /wiki/%E5%A0%AA%E8%90%A8%E6%96%AF%E5%9F%8E [堪薩斯城]

# 外部連結: /wiki/%E7%BD%91%E7%BB%9C%E4%B8%AD%E7%AB%8B%E6%80%A7 [網路中立性]
# 外部連結: /wiki/%E6%96%87%E9%A1%BF%C2%B7%E7%91%9F%E5%A4%AB [文頓·瑟夫]
# 外部連結: /wiki/%E7%BD%91%E9%99%85%E5%8D%8F%E8%AE%AE [網際協定]
# 外部連結: /wiki/%E5%9B%BD%E4%BC%9A [國會]
# 外部連結: /wiki/%E5%9F%83%E9%87%8C%E5%85%8B%C2%B7%E6%96%BD%E5%AF%86%E7%89%B9 [艾瑞克·施密特]
# 外部連結: /wiki/%E9%87%91%E8%9E%8D%E6%97%B6%E6%8A%A5 [金融時報]
# 外部連結: /wiki/%E5%8D%8E%E5%B0%94%E8%A1%97%E6%97%A5%E6%8A%A5 [華爾街日報]
# 外部連結: /wiki/%E6%84%9B%E5%9C%8B%E8%80%85%E6%B3%95%E6%A1%88 [愛國者法案]
# 外部連結: /wiki/Facebook [Facebook]
# 外部連結: /wiki/Cookie [Cookie]
# 外部連結: /wiki/Google_Buzz [Google Buzz]
# 外部連結: /wiki/Gmail [Gmail]
# 外部連結: /wiki/%E8%B0%B7%E6%AD%8C%E9%80%80%E5%87%BA%E4%B8%AD%E5%9B%BD%E4%BA%8B%E4%BB%B6 [退出中國]
# 外部連結: /wiki/%E4%B8%AD%E5%8D%8E%E4%BA%BA%E6%B0%91%E5%85%B1%E5%92%8C%E5%9B%BD%E7%BD%91%E7%BB%9C%E5%AE%A1%E6%9F%A5 [中國大陸的網路審查制度]
# 外部連結: /wiki/%E9%98%B2%E7%81%AB%E9%95%BF%E5%9F%8E [防火長城]
# 外部連結: /wiki/%E7%99%BD%E6%80%9D%E8%B1%AA [白思豪]
# 外部連結: /wiki/Google%E8%A1%97%E6%99%AF [Google街景]
# 外部連結: /wiki/Wi-Fi [Wi-Fi]
# 外部連結: /wiki/%E5%90%89%E5%AD%97%E8%8A%82 [GB]
# 外部連結: /wiki/%E5%BE%B7%E5%9B%BD [德國]
# 外部連結: /wiki/%E6%A3%B1%E9%95%9C%E8%AE%A1%E5%88%92 [稜鏡計劃]
# 外部連結: /wiki/%E4%B8%AD%E5%8D%8E%E4%BA%BA%E6%B0%91%E5%85%B1%E5%92%8C%E5%9B%BD [中國大陸]
# 外部連結: /wiki/%E9%BB%91%E5%AE%A2 [駭客]
# 外部連結: /wiki/%E4%B8%AD%E5%8D%8E%E4%BA%BA%E6%B0%91%E5%85%B1%E5%92%8C%E5%9B%BD%E6%94%BF%E5%BA%9C [中華人民共和國政府]
# 外部連結: /wiki/%E8%B0%B7%E6%AD%8C%E4%B8%AD%E5%9B%BD [谷歌中國]
# 外部連結: /wiki/%E6%90%9C%E7%B4%A2%E5%BC%95%E6%93%8E [搜尋引擎]
# 外部連結: /wiki/%E4%B8%AD%E5%8D%8E%E4%BA%BA%E6%B0%91%E5%85%B1%E5%92%8C%E5%9B%BD%E7%BD%91%E7%BB%9C%E5%AE%A1%E6%9F%A5 [內容審查]
# 外部連結: /wiki/%E7%BD%91%E7%BB%9C%E8%87%AA%E7%94%B1 [網路自由]
# 外部連結: /wiki/%E8%A8%80%E8%AE%BA%E8%87%AA%E7%94%B1 [言論自由]
# 外部連結: /wiki/%E5%8C%97%E4%BA%AC%E6%97%B6%E9%97%B4 [北京時間]
# 外部連結: /wiki/UTC%2B8 [UTC+8]
# 外部連結: /wiki/Google%E9%A6%99%E6%B8%AF [Google香港]
# 外部連結: /wiki/%E9%A6%99%E6%B8%AF [香港]
# 外部連結: /wiki/%E6%9C%8D%E5%8A%A1%E5%99%A8 [伺服器]
# 外部連結: /wiki/%E5%85%B3%E9%94%AE%E8%AF%8D%E8%BF%87%E6%BB%A4 [敏感詞彙]
# 外部連結: /wiki/UTC%2B8 [UTC+8]
# 外部連結: /wiki/%E5%85%AD%E5%9B%9B%E5%A4%A9%E7%BD%91 [六四天網]
# 外部連結: /wiki/%E9%BB%83%E7%90%A6 [黃琦]
# 外部連結: /wiki/%E6%99%AE%E4%B8%96%E5%83%B9%E5%80%BC [普世價值]
# 外部連結: /wiki/%E4%B8%AD%E8%8F%AF%E4%BA%BA%E6%B0%91%E5%85%B1%E5%92%8C%E5%9C%8B%E7%B6%B2%E8%B7%AF%E5%AF%A9%E6%9F%A5 [網路封鎖]
# 外部連結: /wiki/Google%E7%BF%BB%E8%AF%91 [Google翻譯]
# 外部連結: /wiki/Google%E5%9C%B0%E5%9B%BE [Google地圖]
# 外部連結: /wiki/%E5%8D%9A%E5%AE%A2 [部落格]
# 外部連結: /wiki/Google%E4%B8%AD%E5%9B%BD [Google中國]
# 外部連結: /wiki/%E4%B8%AD%E8%8F%AF%E4%BA%BA%E6%B0%91%E5%85%B1%E5%92%8C%E5%9C%8B%E7%B6%B2%E8%B7%AF%E5%AF%A9%E6%9F%A5 [開放網際網路]
# 外部連結: /wiki/%E8%A8%80%E8%AB%96%E8%87%AA%E7%94%B1 [言論自由]
# 外部連結: /wiki/%E4%B8%AD%E8%8F%AF%E4%BA%BA%E6%B0%91%E5%85%B1%E5%92%8C%E5%9C%8B%E6%96%B0%E8%81%9E%E8%87%AA%E7%94%B1 [新聞檢查制度]
# 外部連結: /wiki/%E9%98%B2%E7%81%AB%E9%95%B7%E5%9F%8E [防火長城]
# 外部連結: /wiki/2014%E5%B9%B4%E4%B8%AD%E5%9B%BD%E5%A4%A7%E9%99%86%E5%B1%8F%E8%94%BD%E8%B0%B7%E6%AD%8C%E6%9C%8D%E5%8A%A1%E4%BA%8B%E4%BB%B6 [大規模干擾至基本無法使用]
# 外部連結: /wiki/Google%E9%A6%99%E6%B8%AF [Google香港]
# 外部連結: /wiki/Google%E5%9C%B0%E5%9B%BE [地圖]
# 外部連結: /wiki/Google%E7%BF%BB%E8%AF%91 [翻譯]
# 外部連結: /wiki/265%E4%B8%8A%E7%BD%91%E5%AF%BC%E8%88%AA [網站導航服務]
# 外部連結: /wiki/Gmail [Gmail]
# 外部連結: /wiki/%E7%99%BE%E5%BA%A6 [百度]
# 外部連結: /wiki/%E4%BF%84%E7%BE%85%E6%96%AF [俄羅斯]
# 外部連結: /wiki/%E8%81%AF%E5%90%88%E5%9C%8B [聯合國]
# 外部連結: /wiki/%E5%9C%8B%E9%9A%9B%E9%9B%BB%E4%BF%A1%E8%81%AF%E7%9B%9F [國際電信聯盟]
# 外部連結: /wiki/%E7%B6%B2%E6%B0%91 [網友]
# 外部連結: /wiki/%E4%B8%AD%E5%9C%8B%E4%BA%92%E8%81%AF%E7%B6%B2%E7%B5%A1%E4%BF%A1%E6%81%AF%E4%B8%AD%E5%BF%83 [中國互聯網絡信息中心]
# 外部連結: /wiki/%E5%AE%89%E5%85%A8%E8%AD%89%E6%9B%B8 [安全憑證]
# 外部連結: /wiki/Google_Chrome [Google Chrome]
# 外部連結: /wiki/File:Nuvola_apps_important_yellow.svg []
# 外部連結: /wiki/UTC%2B08:00 [東八區]
# 外部連結: /wiki/Google%E6%90%9C%E5%B0%8B [Google搜尋]
# 外部連結: /wiki/YouTube [YouTube]
# 外部連結: /wiki/Google_Drive [Google Drive]
# 外部連結: /wiki/Gmail [Gmail]
